# %% [markdown]
# # Predictive Modeling for Tax_due Prediction Using Machine Learning.

# %% [markdown]
# ## Name :Thasleema.k

# %% [markdown]
# ## Organization : EntryElevate

# %% [markdown]
# ## Submission date : 25/09/2024

# %% [markdown]
# ## Table of content

# %% [markdown]
# ### 1.Overview of Problem Statement
#
# ### 2.Objective
#
# ### 3.Data Collection
#
# ### 4.Data Description
#
# ### 5.Exploratory Data Analysis (EDA)
#
# ### 6.Data Preprocessing
#
# ### 7.Visualization
#
# ### 8.Feature Engineering
#
# ### 9.Data Splitting
#
# ### 10.Model Selection
#
# ### 11.Model Training & Evaluation
#
# ### 12.Feature Selection
#
# ### 13.Model Evaluation
#
# ### 14.Hyperparameter Tuning
#
# ### 15.Results
#
# ### 16.Model Deployment
#
# ### 17.Limitations
#
# ### 18.Conclusion

# %% [markdown]
# ## 1. Overview of Problem Statement

# %% [markdown]
# ### The problem statement can be summarized as follows:

# %% [markdown]
# * #### 1.Business Challenge:

# %% [markdown]
# #### Residential property owners need to understand the factors that significantly impact their tax. By accurately predicting the tax, they can make informed decisions regarding pricing and customer engagement.

# %% [markdown]
# * #### 2.Technical Challenge:

# %% [markdown]
# #### The real-estate dataset includes both numerical and categorical features, requiring appropriate preprocessing and feature engineering. Identifying the most relevant features that contribute to tax_due prediction. Developing and evaluating different machine learning models to find the best-performing one for predicting tax_due.

# %% [markdown]
# ## 2. Objective

# %% [markdown]
# ### To develop a predictive model that accurately forecasts the tax of residential property based on a variety of factors and other relevant attributes. The ultimate goal is to provide actionable insights that property owners can use to optimize their operations.

# %%
# Ignore warninggs
import warnings
warnings.filterwarnings('ignore')
#this code is used to supress warning messages.

# %% [markdown]
# ## 3.Data Collection

# %%
# this code reads the dataset from csv file located at the specified path into a pandas dataframe named "df"
import pandas as pd
df=pd.read_csv("C:\\Users\\Faheem\\Downloads\\residential-property-tax-payments-from-2010-to-current-1.csv")
df
# Out:
#           YR    BILL_TYPE  BILL_NUM  PARCEL_ID  \
# 0       2010  Residential     12351  264169027
# 1       2010  Residential      5621  142707053
# 2       2010  Residential     19109  203423193
# 3       2010  Residential      2671  284074072
# 4       2010  Residential     17625  221270024
# ...      ...          ...       ...        ...
# 136040  2017  Residential     25380  227544074
# 136041  2017  Residential     16312  147018080
# 136042  2017  Residential     11083  193055038
# 136043  2017  Residential     25174  999999064
# 136044  2017  Residential     25486  227544084
#
#                              TXPR_NAME              CO_NAME  \
# 0                  LYTTLETON PRISCILLA  LYTTLETON KEITHTOUS
# 1                   CZARNECKI EUGENE B                  NaN
# 2       SOUTHERN NEW ENGLAND CONFERENC                  NaN
# 3                      BROWN DERMOTH H                  NaN
# 4                        ROSCOE THOMAS                  NaN
# ...                                ...                  ...
# 136040       WASHINGTON DEVELOPERS LLC                  NaN
# 136041             CASTLEROCK 2017 LLC                  NaN
# 136042            IRVING VIOLET LOUISE                  NaN
# 136043                   CROWN GARDENS                  NaN
# 136044       WASHINGTON DEVELOPERS LLC                  NaN
#
#                              MAIL_ADDR       MAIL_ADDR2           CITY STATE  \
# 0                      297 BELLEVUE ST              NaN       HARTFORD    CT
# 1                   809 NEW BRITAIN AV              NaN       HARTFORD    CT
# 2                           PO Box 269              NaN       HARTFORD    CT
# 3                         3372 MAIN ST              NaN       HARTFORD    CT
# 4                      228 DAVENTRY DR              NaN         DEBARY    FL
# ...                                ...              ...            ...   ...
# 136040                5 MARINA VIEW DR              NaN        CHESTER    CT
# 136041  333 WESTCHESTER AV WEST BUILDI              NaN   WHITE PLAINS    NY
# 136042            111 EAST 14TH STREET  c/o Mark Irving       NEW YORK    NY
# 136043           PROPERTY SERVICES INC    PO BOX 330487  WEST HARTFORD    CT
# 136044                5 MARINA VIEW DR              NaN        CHESTER    CT
#
#          ZIP1  ZIP2 PROP_LOC_NUM   PROP_LOC_NAME LIEN_SOLD   BILLED     PAID  \
# 0        6120  2104          303     BELLEVUE ST       NaN   891.34    62.18
# 1        6106  3918          809  NEW BRITAIN AV         Y     0.00     0.00
# 2        6141     0          156         RUSS ST         Y  1458.38  1458.38
# 3        6120  1109         3364         MAIN ST       NaN  2373.16  1916.40
# 4       32713  2137          312       GARDEN ST       NaN  2381.56  2381.56
# ...       ...   ...          ...             ...       ...      ...      ...
# 136040   6412     0      323-327   WASHINGTON ST       NaN  1216.06     0.00
# 136041  10604     0          161       HAROLD ST       NaN  2592.94     0.00
# 136042  10003     0           27    WOODSTOCK ST       NaN  2193.42     0.00
# 136043   6133     0           26      ENFIELD ST       NaN     0.00     0.00
# 136044   6412     0          333   WASHINGTON ST       NaN  1331.66     0.00
#
#         TAX_DUE
# 0        829.16
# 1          0.00
# 2          0.00
# 3        456.76
# 4          0.00
# ...         ...
# 136040  1216.06
# 136041  2592.94
# 136042  2193.42
# 136043     0.00
# 136044  1331.66
#
# [136045 rows x 18 columns]

# %%
df.head()
# Out:
#      YR    BILL_TYPE  BILL_NUM  PARCEL_ID                       TXPR_NAME  \
# 0  2010  Residential     12351  264169027             LYTTLETON PRISCILLA
# 1  2010  Residential      5621  142707053              CZARNECKI EUGENE B
# 2  2010  Residential     19109  203423193  SOUTHERN NEW ENGLAND CONFERENC
# 3  2010  Residential      2671  284074072                 BROWN DERMOTH H
# 4  2010  Residential     17625  221270024                   ROSCOE THOMAS
#
#                CO_NAME           MAIL_ADDR MAIL_ADDR2      CITY STATE   ZIP1  \
# 0  LYTTLETON KEITHTOUS     297 BELLEVUE ST        NaN  HARTFORD    CT   6120
# 1                  NaN  809 NEW BRITAIN AV        NaN  HARTFORD    CT   6106
# 2                  NaN          PO Box 269        NaN  HARTFORD    CT   6141
# 3                  NaN        3372 MAIN ST        NaN  HARTFORD    CT   6120
# 4                  NaN     228 DAVENTRY DR        NaN    DEBARY    FL  32713
#
#    ZIP2 PROP_LOC_NUM   PROP_LOC_NAME LIEN_SOLD   BILLED     PAID  TAX_DUE
# 0  2104          303     BELLEVUE ST       NaN   891.34    62.18   829.16
# 1  3918          809  NEW BRITAIN AV         Y     0.00     0.00     0.00
# 2     0          156         RUSS ST         Y  1458.38  1458.38     0.00
# 3  1109         3364         MAIN ST       NaN  2373.16  1916.40   456.76
# 4  2137          312       GARDEN ST       NaN  2381.56  2381.56     0.00

# %%
df.tail()
# Out:
#           YR    BILL_TYPE  BILL_NUM  PARCEL_ID                  TXPR_NAME  \
# 136040  2017  Residential     25380  227544074  WASHINGTON DEVELOPERS LLC
# 136041  2017  Residential     16312  147018080        CASTLEROCK 2017 LLC
# 136042  2017  Residential     11083  193055038       IRVING VIOLET LOUISE
# 136043  2017  Residential     25174  999999064              CROWN GARDENS
# 136044  2017  Residential     25486  227544084  WASHINGTON DEVELOPERS LLC
#
#        CO_NAME                       MAIL_ADDR       MAIL_ADDR2  \
# 136040     NaN                5 MARINA VIEW DR              NaN
# 136041     NaN  333 WESTCHESTER AV WEST BUILDI              NaN
# 136042     NaN            111 EAST 14TH STREET  c/o Mark Irving
# 136043     NaN           PROPERTY SERVICES INC    PO BOX 330487
# 136044     NaN                5 MARINA VIEW DR              NaN
#
#                  CITY STATE   ZIP1  ZIP2 PROP_LOC_NUM  PROP_LOC_NAME  \
# 136040        CHESTER    CT   6412     0      323-327  WASHINGTON ST
# 136041   WHITE PLAINS    NY  10604     0          161      HAROLD ST
# 136042       NEW YORK    NY  10003     0           27   WOODSTOCK ST
# 136043  WEST HARTFORD    CT   6133     0           26     ENFIELD ST
# 136044        CHESTER    CT   6412     0          333  WASHINGTON ST
#
#        LIEN_SOLD   BILLED  PAID  TAX_DUE
# 136040       NaN  1216.06   0.0  1216.06
# 136041       NaN  2592.94   0.0  2592.94
# 136042       NaN  2193.42   0.0  2193.42
# 136043       NaN     0.00   0.0     0.00
# 136044       NaN  1331.66   0.0  1331.66

# %% [markdown]
# ## 4. Data Description

# %% [markdown]
# #### Data Source : https://data.world/datasets/free

# %% [markdown]
# ### The dataset consists of the following columns:
# * YR: Year of the property tax payment, indicating the year for which the payment was recorded.
# * BILL_TYPE: The type of bill(property tax)
# * BILL_NUM: Bill number for each bill.
# * PARCEL-ID: specific code assigned to each plot of land for taxation and record-keeping purposes.
# * TXPR_NAME: Taxpayer's name.
# * CO_NAME: company name
# * MAIL_ADDR: The mailing address associated with the taxpayer.
# * MAIL_ADDR2: The mailing address associated with the taxpayer.
# * CITY:  city of the taxpayer’s mailing address.
# * STATE:  state of the taxpayer’s mailing address.
# * ZIP1: zip code of the taxpayer’s mailing address 1.
# * ZIP2: zip code of the taxpayer’s mailing address 2.
# * PROP_LOC_NUM: Property location number
# * LIEN_SOLD: indicates whether a tax lien on a property has been sold.(A tax lien is a legal claim by the government on a property when the property owner fails to pay the taxes owed.)
# * BILLED: The amount billed for taxes.
# * PAID: The amount paid by the taxpayer.
# * TAX_DUE: The amount of tax owed.

# %% [markdown]
# #### Dataset Size:
# * The total number of records:136045
# *  Number of features: 18

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#           YR    BILL_TYPE  BILL_NUM  PARCEL_ID  \
# 0       2010  Residential     12351  264169027
# 1       2010  Residential      5621  142707053
# 2       2010  Residential     19109  203423193
# 3       2010  Residential      2671  284074072
# 4       2010  Residential     17625  221270024
# ...      ...          ...       ...        ...
# 136040  2017  Residential     25380  227544074
# 136041  2017  Residential     16312  147018080
# 136042  2017  Residential     11083  193055038
# 136043  2017  Residential     25174  999999064
# 136044  2017  Residential     25486  227544084
#
#                              TXPR_NAME              CO_NAME  \
# 0                  LYTTLETON PRISCILLA  LYTTLETON KEITHTOUS
# 1                   CZARNECKI EUGENE B                  NaN
# 2       SOUTHERN NEW ENGLAND CONFERENC                  NaN
# 3                      BROWN DERMOTH H                  NaN
# 4                        ROSCOE THOMAS                  NaN
# ...                                ...                  ...
# 136040       WASHINGTON DEVELOPERS LLC                  NaN
# 136041             CASTLEROCK 2017 LLC                  NaN
# 136042            IRVING VIOLET LOUISE                  NaN
# 136043                   CROWN GARDENS                  NaN
# 136044       WASHINGTON DEVELOPERS LLC                  NaN
#
#                              MAIL_ADDR       MAIL_ADDR2           CITY STATE  \
# 0                      297 BELLEVUE ST              NaN       HARTFORD    CT
# 1                   809 NEW BRITAIN AV              NaN       HARTFORD    CT
# 2                           PO Box 269              NaN       HARTFORD    CT
# 3                         3372 MAIN ST              NaN       HARTFORD    CT
# 4                      228 DAVENTRY DR              NaN         DEBARY    FL
# ...                                ...              ...            ...   ...
# 136040                5 MARINA VIEW DR              NaN        CHESTER    CT
# 136041  333 WESTCHESTER AV WEST BUILDI              NaN   WHITE PLAINS    NY
# 136042            111 EAST 14TH STREET  c/o Mark Irving       NEW YORK    NY
# 136043           PROPERTY SERVICES INC    PO BOX 330487  WEST HARTFORD    CT
# 136044                5 MARINA VIEW DR              NaN        CHESTER    CT
#
#          ZIP1  ZIP2 PROP_LOC_NUM   PROP_LOC_NAME LIEN_SOLD   BILLED     PAID  \
# 0        6120  2104          303     BELLEVUE ST       NaN   891.34    62.18
# 1        6106  3918          809  NEW BRITAIN AV         Y     0.00     0.00
# 2        6141     0          156         RUSS ST         Y  1458.38  1458.38
# 3        6120  1109         3364         MAIN ST       NaN  2373.16  1916.40
# 4       32713  2137          312       GARDEN ST       NaN  2381.56  2381.56
# ...       ...   ...          ...             ...       ...      ...      ...
# 136040   6412     0      323-327   WASHINGTON ST       NaN  1216.06     0.00
# 136041  10604     0          161       HAROLD ST       NaN  2592.94     0.00
# 136042  10003     0           27    WOODSTOCK ST       NaN  2193.42     0.00
# 136043   6133     0           26      ENFIELD ST       NaN     0.00     0.00
# 136044   6412     0          333   WASHINGTON ST       NaN  1331.66     0.00
#
#         TAX_DUE
# 0        829.16
# 1          0.00
# 2          0.00
# 3        456.76
# 4          0.00
# ...         ...
# 136040  1216.06
# 136041  2592.94
# 136042  2193.42
# 136043     0.00
# 136044  1331.66
#
# [136045 rows x 18 columns]

# %% [markdown]
# ## 5.Exploratory Data Analysis

# %%
# To get the dimension of the dataset
df.shape
# Out:
# (136045, 18)

# %%
# To get the concise summary of a Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136045 entries, 0 to 136044
# Data columns (total 18 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   YR             136045 non-null  int64
#  1   BILL_TYPE      136045 non-null  object
#  2   BILL_NUM       136045 non-null  int64
#  3   PARCEL_ID      136045 non-null  int64
#  4   TXPR_NAME      136045 non-null  object
#  5   CO_NAME        34288 non-null   object
#  6   MAIL_ADDR      136040 non-null  object
#  7   MAIL_ADDR2     4900 non-null    object
#  8   CITY           136034 non-null  object
#  9   STATE          136010 non-null  object
#  10  ZIP1           136045 non-null  int64
#  11  ZIP2           136045 non-null  int64
#  12  PROP_LOC_NUM   135988 non-null  object
#  13  PROP_LOC_NAME  136044 non-null  object
#  14  LIEN_SOLD      3429 non-null    object
#  15  BILLED         136045 non-null  float64
#  16  PAID           136045 non-null  float64
#  17  TAX_DUE        136045 non-null  float64
# dtypes: float64(3), int64(5), object(10)
# memory usage: 18.7+ MB

# %%
# columns
df.columns
# Out:
# Index(['YR', 'BILL_TYPE', 'BILL_NUM', 'PARCEL_ID', 'TXPR_NAME', 'CO_NAME',
#        'MAIL_ADDR', 'MAIL_ADDR2', 'CITY', 'STATE', 'ZIP1', 'ZIP2',
#        'PROP_LOC_NUM', 'PROP_LOC_NAME', 'LIEN_SOLD', 'BILLED', 'PAID',
#        'TAX_DUE'],
#       dtype='object')

# %%
# Data types of each columns in the dataframe
df.dtypes
# Out:
# YR                 int64
# BILL_TYPE         object
# BILL_NUM           int64
# PARCEL_ID          int64
# TXPR_NAME         object
# CO_NAME           object
# MAIL_ADDR         object
# MAIL_ADDR2        object
# CITY              object
# STATE             object
# ZIP1               int64
# ZIP2               int64
# PROP_LOC_NUM      object
# PROP_LOC_NAME     object
# LIEN_SOLD         object
# BILLED           float64
# PAID             float64
# TAX_DUE          float64
# dtype: object

# %% [markdown]
# ### Identifying numerical and categorical columns

# %%
# Selecting all numeric columns (both integers and floats)
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

print("Numeric Columns (including both integers and floats):")
print(num_cols)
# Out:
# Numeric Columns (including both integers and floats):
# Index(['YR', 'BILL_NUM', 'PARCEL_ID', 'ZIP1', 'ZIP2', 'BILLED', 'PAID',
#        'TAX_DUE'],
#       dtype='object')

# %%
# Categorical columns
cat_cols = df.select_dtypes(include=['object','datetime']).columns
print(cat_cols)
# Out:
# Index(['BILL_TYPE', 'TXPR_NAME', 'CO_NAME', 'MAIL_ADDR', 'MAIL_ADDR2', 'CITY',
#        'STATE', 'PROP_LOC_NUM', 'PROP_LOC_NAME', 'LIEN_SOLD'],
#       dtype='object')

# %%
# finding missing /null values
df.isnull().sum()
# Out:
# YR                    0
# BILL_TYPE             0
# BILL_NUM              0
# PARCEL_ID             0
# TXPR_NAME             0
# CO_NAME          101757
# MAIL_ADDR             5
# MAIL_ADDR2       131145
# CITY                 11
# STATE                35
# ZIP1                  0
# ZIP2                  0
# PROP_LOC_NUM         57
# PROP_LOC_NAME         1
# LIEN_SOLD        132616
# BILLED                0
# PAID                  0
# TAX_DUE               0
# dtype: int64

# %% [markdown]
# ### Out of 18 columns, 8 are numerical and 10 are categorical

# %%
# percentage of missing values in each column
df.isnull().sum()/df.shape[0]*100
# Out:
# YR                0.000000
# BILL_TYPE         0.000000
# BILL_NUM          0.000000
# PARCEL_ID         0.000000
# TXPR_NAME         0.000000
# CO_NAME          74.796575
# MAIL_ADDR         0.003675
# MAIL_ADDR2       96.398251
# CITY              0.008086
# STATE             0.025727
# ZIP1              0.000000
# ZIP2              0.000000
# PROP_LOC_NUM      0.041898
# PROP_LOC_NAME     0.000735
# LIEN_SOLD        97.479510
# BILLED            0.000000
# PAID              0.000000
# TAX_DUE           0.000000
# dtype: float64

# %% [markdown]
# #### if percentage of missing values is greater than 50%, we can drop that columns

# %% [markdown]
# #### The columns "CO_NAME","MAIL_ADDR2", "LIEN_SOLD" contain almost missing values, so that those can be droped from the dataset.

# %%
#Check the number of NaN values in the TAX_DUE column.
nan_count = df['TAX_DUE'].isna().sum()
print(f'Total NaN values in TAX_DUE: {nan_count}')
# Out:
# Total NaN values in TAX_DUE: 0

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### There are no duplicate values

# %% [markdown]
# ## Understand the distribution of data

# %%
# Statistical summary of numerical column
df.describe().T
# Out:
#               count          mean           std          min           25%  \
# YR         136045.0  2.014496e+03  1.777353e+00       2010.0  2.013000e+03
# BILL_NUM   136045.0  2.076556e+04  3.777817e+04          1.0  6.769000e+03
# PARCEL_ID  136045.0  2.012499e+08  5.487155e+07  102001001.0  1.625051e+08
# ZIP1       136045.0  7.579930e+03  8.480252e+03          0.0  6.106000e+03
# ZIP2       136045.0  1.401709e+03  1.565618e+03       -530.0  0.000000e+00
# BILLED     136045.0  8.536565e+03  7.707653e+04      -3681.8  2.067500e+03
# PAID       136045.0  7.845229e+03  7.155735e+04      -3661.0  1.622560e+03
# TAX_DUE    136045.0  6.913355e+02  1.633742e+04    -238900.5  0.000000e+00
#
#                     50%           75%           max
# YR         2.015000e+03  2.016000e+03  2.017000e+03
# BILL_NUM   1.350100e+04  2.024000e+04  1.000003e+06
# PARCEL_ID  1.982081e+08  2.442881e+08  9.999992e+08
# ZIP1       6.112000e+03  6.114000e+03  9.840900e+04
# ZIP2       1.126000e+03  2.418000e+03  9.792000e+03
# BILLED     3.295220e+03  4.444480e+03  5.473181e+06
# PAID       3.129920e+03  4.264100e+03  5.469784e+06
# TAX_DUE    0.000000e+00  0.000000e+00  2.593094e+06

# %%
# statistical summary of  categorical columns 
df.describe(include='object').T
# Out:
#                 count unique                    top    freq
# BILL_TYPE      136045      1            Residential  136045
# TXPR_NAME      136045  22180    BUSHNELL CONDOS LLC    1459
# CO_NAME         34288   6791         MAGALHAES ROSA      90
# MAIL_ADDR      136040  20052      621 FARMINGTON AV    2711
# MAIL_ADDR2       4900    772  C/O NAFTALI STEINMETZ     324
# CITY           136034    863               HARTFORD   96529
# STATE          136010     55                     CT  122033
# PROP_LOC_NUM   135988   1584                    100    3208
# PROP_LOC_NAME  136044   3995                MAIN ST    2008
# LIEN_SOLD        3429      1                      Y    3429

# %% [markdown]
# ### Finding Outliers

# %%
import matplotlib.pyplot as plt
from scipy.stats import zscore
# Calculate Z-scores for numerical columns
z_scores = df[num_cols].apply(zscore)

# Define threshold for outliers (typically |Z-score| > 3)
threshold = 3

# Boolean array where True indicates presence of outliers
outliers = (np.abs(z_scores) > threshold).any(axis=1)

# Select rows containing outliers
outliers_df = df[outliers]

# %%
for col in num_cols:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Select numerical columns from the DataFrame
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Loop through each numerical column and create scatter plots against 'TAX_DUE'
for col in num_cols:
    if col != 'TAX_DUE':
        plt.figure(figsize=(10, 6))
        sns.scatterplot(x=col, y='TAX_DUE', data=df)
        plt.title(f'Scatter Plot of {col} vs TAX_DUE')
        plt.xlabel(col)
        plt.ylabel('TAX_DUE')
        plt.grid(True)
        plt.show()

# %% [markdown]
# ### Skewness and Kurtosis

# %%
from scipy.stats import skew, kurtosis

#claculate skewness and kurtosis
skewness = df[num_cols].apply(skew)
kurt = df[num_cols].apply(lambda x: kurtosis(x,fisher=False))

print(skewness)
print(kurt)

#Identify positive and negative skewness (absolute value>1)
positive_skewness = skewness[skewness > 1]
negative_skewness = skewness[skewness < -1]

print('variable with positive skewness (skew > 1):\n', positive_skewness)
print('variable with negative skewness (skew < -1):\n', negative_skewness)

# Identify the platykurtic (kurtosis < 3) and leptokurtic (kurtosis > 3) distributions
platykurtic = kurt[kurt < 3]
leptokurtic = kurt[kurt > 3]

print('variables with platykurtic distribution (kurtosis < 3):\n', platykurtic)
print('variables with leptokurtic distribution (kurtosis > 3):\n', leptokurtic)
# Out:
# YR            -0.109095
# BILL_NUM      10.374518
# PARCEL_ID      3.837283
# ZIP1           7.743395
# ZIP2           1.018305
# BILLED        43.866513
# PAID          44.622972
# TAX_DUE      104.879384
# dtype: float64
# YR               1.873613
# BILL_NUM       138.391182
# PARCEL_ID       56.904924
# ZIP1            67.557507
# ZIP2             3.953684
# BILLED        2330.953121
# PAID          2438.336953
# TAX_DUE      13516.229573
# dtype: float64
# variable with positive skewness (skew > 1):
#  BILL_NUM      10.374518
# PARCEL_ID      3.837283
# ZIP1           7.743395
# ZIP2           1.018305
# BILLED        43.866513
# PAID          44.622972
# TAX_DUE      104.879384
# dtype: float64
# variable with negative skewness (skew < -1):
#  Series([], dtype: float64)
# variables with platykurtic distribution (kurtosis < 3):
#  YR    1.873613
# dtype: float64
# variables with leptokurtic distribution (kurtosis > 3):
#  BILL_NUM       138.391182
# PARCEL_ID       56.904924
# ZIP1            67.557507
# ZIP2             3.953684
# BILLED        2330.953121
# PAID          2438.336953
# TAX_DUE      13516.229573
# dtype: float64

# %% [markdown]
# #### The target variable'TAX_DUE' is almost constant (i.e., most values are '0'), skewness and kurtosis might result in NaN or very high values

# %% [markdown]
# ### Skewness:
#  * Positive Skewness: 'BILL_NUM','PARCEL_ID','ZIP1','ZIP2','BILLED','PAID','TAX_DUE' have positive skewness, indicating a longer right tail.
#  * Negative Skewness: None of the variables have significant negative skewness. tail.

# %% [markdown]
# ### Kurtosis:
# * Platykurtic Distribution:variable 'YR' have a flatter distribution (kurtosis < 3).
# * Leptokurtic Distribution: 'BILL_NUM','PARCEL_ID','ZIP1','ZIP2','BILLED','PAID','TAX_DUE' have a sharper peak and heavier tails (kurtosis > 3). > 3).

# %% [markdown]
# ### Implications for Model Building:
# * Positive Skewness: 'BILL_NUM','PARCEL_ID','ZIP1','ZIP2','BILLED','PAID','TAX_DUE'  may need transformation to reduce skewness for better model performance.
# * Platykurtic Variables: variable 'YR' have flatter distribution, indicating outlier influence.
# * Leptokurtic Variables:'BILL_NUM','PARCEL_ID','ZIP1','ZIP2','BILLED','PAID','TAX_DUE' have sharper peaks and heavier tails, which may affect model sensitivity to  outliers.

# %%
# Correlation heatmap
# Assuming df is our DataFrame as provided
# Drop non-numeric columns before computing correlation
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
corr_matrix = df[numeric_columns].corr()

# Plotting the heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### insights:The heatmap provides a visual representation of the correlations between different numerical features in my dataset. Here are some key insights:

# %% [markdown]
# ### 1.Positive Correlation with TAX_DUE:
# * BILLED(0.43),PAID(0.24): These are the 2 columns that positively correlate with TAX_DUE

# %% [markdown]
# ### 2.Multicollinearity:
# * PAID and BILLED(0.98): These two features are highly correlated, suggesting multicollinearity.
# * Drop Recommendation:Given the high correlation (0.98) between PAID and BILLED,I can drop both features to reduce multicollinearity.

# %% [markdown]
# ### Analysing Categorical columns

# %%
for col in cat_cols:
    print(f"Values in {col}:\n{df[col].unique()}")
    print(f"Number of unique values in {col}: {df[col].nunique()}\n")
# Out:
# Values in BILL_TYPE:
# ['Residential']
# Number of unique values in BILL_TYPE: 1
#
# Values in TXPR_NAME:
# ['LYTTLETON PRISCILLA' 'CZARNECKI EUGENE B'
#  'SOUTHERN NEW ENGLAND CONFERENC' ... 'FRANKLIN GARDENS' 'SOUTH PLACE'
#  'LAUREL ST CONDOS']
# Number of unique values in TXPR_NAME: 22180
#
# Values in CO_NAME:
# ['LYTTLETON KEITHTOUS' nan 'HAYNES EUGENE JR ESTATE' ...
#  'C/O CAPSTONE MGMT' 'C/O ADVANCE PROPERTY MANAGEMEN' 'C/O JOHN F LEE']
# Number of unique values in CO_NAME: 6791
#
# Values in MAIL_ADDR:
# ['297 BELLEVUE ST' '809 NEW BRITAIN AV' 'PO Box 269' ... '145 GEORGE ST'
#  '362 LAUREL ST' 'PROPERTY SERVICES INC']
# Number of unique values in MAIL_ADDR: 20052
#
# Values in MAIL_ADDR2:
# [nan 'C/O VESPASIAN  LLC' '95 NILES STREET' 'DBA HAVANA GROUP'
#  '7 CLEVELAND AV UNIT 0102' 'Apt.G-1' '433 SO MAIN ST SUITE 328'
#  'AIMCO/TTA MS 235' 'PO BOX 53' '101 N. TRYON STREET' 'C/O CAPSTONE MGMT.'
#  'c/o ZGS COMMUNICATIONS' 'APT 2132' 'C/O ORL PROPERTY MANAGEMENT'
#  'c/o American Home Mortgage Ser' 'C/O SUMMIT MEDICAL'
#  'C/O BROAD PARK DEV CORP' 'C/O IMAGINEERS' 'c/o MARVIN F. POER & COMPANY'
#  'C/O ASONS' 'ATTN: TAX DEPT' 'C/O ADA  MITLITSKY'
#  'ATTN: SHIPMAN & GOODWIN' '#38' 'C/O PAULMAN REALTY' 'C/O MARTIN MEDIA'
#  'SUITE 600' '1411 WALNUT ST 3RD FL' 'FBO BERYL E POPE #071464'
#  'P.O. BOX 270027' 'C/O BETTER LOAN SOCIETY INC.'
#  '1548 NORTH COMMERCIAL RD' 'c/o Cityside Corp' 'COCONUT CREEK'
#  'c/o WILLIAM J BUMSTER ESQ.' 'C/O LESTER  HICKS' 'P.O. BOX 13'
#  'SUITE 210' 'ATTN: NASHA LEWIS' 'C/O CBRE-CC# 00424' 'C/O CBRE-CC# 04505'
#  'c/o DANIAL LANZA' 'C/O MILL MGMT  INC.' 'CHEROKEE ST'
#  'AERO ALL GAS COMPANY' 'C/O CBRE-CC# 00343' 'C/O CHRISTINE M BACON'
#  'C/O BOB LIGHTFOOT' 'C/O JIFFY LUBE #267 PROP.TAX.D' 'CV-3105'
#  'C/O PAYTRUST' 'C/O C H F A FINANCE  DEPT.' '1 FL'
#  'C/O PROSPECT ENTERPRISES' 'ATTN: KETTLYNE ROCHE' 'APT 12E'
#  '2 GALLERIA TOWER  SUITE 950' 'C/O MECHANICS SAVINGS  BANK'
#  'C/O MICHAEL C MCCULLOUGH' 'C/O DENISE S HARRIS'
#  'c/o Common Ground Communities' 'C/O ELDER ROLLE' '1ST FLOOR'
#  'C/O DORIS AIKEN FORD' 'ATTENTION TREASURER' 'C/O OWENS RENZ & LEE CO'
#  'ATTN: COMMERCIAL TAX SERVICE 1' 'C/O APT A2' 'TORONTO'
#  'C/O STS GROUP INC' 'C/O SONIA DEBEATHAM' 'BOX 517' 'c/o MMR INVESTMENTS'
#  'SUITE 10A' 'C/O EST. OF SNOW GENE MUNFOR' 'C/O BYRON  TYRELL'
#  'PO BOX 269' '10 COLUMBUS BLVD 2ND FL' 'C/O MARSHALL POMER'
#  'C/O FLEAGANE ENTERPRISE' 'C/O KONOVER RESIDENTIAL CORP.'
#  'C/O ROBERT  LESSER' '16 KITTS LANE' '18 CAMPO BELLO ST'
#  'C/O PARK BROAD INVESTMENTS' 'c/o Greene Law  PC' 'C/O SIEGEL O`CONNOR'
#  'C/O KIMBERLY WALKER' 'C/O 960 MAIN LLC' 'C/O ROGER PEPIN'
#  'C/O CHIF ATT. CINDI RUGGERI' 'C/O DENISE  CALLAHAN'
#  'c/o CITIMORTGAGE INC.' 'C/O BATOOL H. RIZVI' 'C/O DONALD M WILLIAMS'
#  'c/o Gregory W. McCracken' 'C/O JOHN D THAYER ADM'
#  'C/O JRH ASSET MANAGEMENT LLC' 'C/O CENTRAL CT HOLDINGS LLC'
#  'C/O TRIAD REAL ESTATE SERVICES' 'APT 5' 'C/O WILLIAM GOOGE JR' 'APT 807'
#  'C/O KENNETH E. HESTER' 'c/o Yvonne Elaine Ross' 'C/O Mark C. Yellin'
#  'c/o JOEL ROACH' 'C/O VICKYE WARD' '3B' 'C/O ZYGMUNT  KAROLISZYN'
#  'C/O MMR INVESTMENTS' 'C/O FINANCE DEPT' 'MATAZZ MANAGEMENT'
#  'C/O FRANK STAVOLA' 'c/o Case & Case P.C.' 'C/O BRANDON SIMS'
#  'C/O HENRY WINIARSKI ESQ.' 'C/O TRIAD REAL ESTATE' '2ND FLOOR'
#  'C/O CENTRAL CONNECTICUT HOLDIN' 'ATTN: TAX DEPARTMENT'
#  'C/O JOHN T FORREST' 'C/O COMMON GROUND COMMUNITIES'
#  'ATTN: KATHERINE HALLER' 'c/o MARVIN F. POER & CO.'
#  'C/O BRUCE G MACDERMID' 'c/o Anatoly Braylovsky & Adria'
#  'c/o RM Bradley Management' 'C/O HARVEY ELGART' 'C/O SATURN RENTALS LLC'
#  'F-93100 MONTREUIL S/BOIS' 'C/O PLAZA REALTY INC.' 'C/O PLAZA REALTY INC'
#  'C/O RELIANT PROPERTY MGMT.' 'C/O HIGHLAND MANAGEMENT'
#  '1 LINDEN PL SUITE 108' '1195 RT 70 SUITE 2000'
#  'C/O OFFICE OF POLICY & MANAGEM' 'C/O NAFTALI STEINMETZ'
#  'C/O LAMAR ADVERTISING' 'c/o MARIE MAZZOTTA' 'c/o Reliant Property Mgmt.'
#  'c/o Arbor Commercial Funding' '56 NOOK FARMS RD' 'TREASURER CC 326'
#  'PO BOX 1169' 'ATTY RICHARD LEIBERT' 'c/o Mutual Housing Association'
#  'C/O BRUCE M FRAISTAT' 'C/O SINA' 'c/o Ingram Yuzek Gainen & Bert'
#  'C/O KONOVER INVESTMENTS CORP.' 'ATTN: MEG SAKELLARIDES'
#  'C/O PYNE-DAVIDSON CORP' 'C/O I CARE MANAGEMENT' 'C/O JOHN J ALGIERE'
#  'SUITE 950' 'C/O BARBARA LONDON' 'c/o FRANCINE DAVIS EARLY'
#  'C/O PATRICIA N  MIEREZ' 'c/o Jonathan Clark' 'C/O CITY MORTGAGE'
#  'C/O REID AND RIEGE P.C.' 'C/O HTFD AREA HABITAT'
#  'C/O REAL ESTATE STAFF SERVICES' 'C/O MARVIN F POER AND COMPANY'
#  '159 HIGH ST' 'C/O NATIONWIDE POSTAL MGMT.'
#  'c/o Michaelson Conner & Boul' 'c/o Utility Shared Services-Lo'
#  'C/O HARRY COHEN' 'c/o STATE MARKET HARTFORD LLC' 'C/O S.B. ASHLEY MGMT'
#  'c/o Americas Servicing Co.' 'C/O KONOVER PROPERTIES CORP'
#  'C/O STS GROUP  INC' '23 JILLIAN CIRCLE' 'C/O PRIME HEALTHCARE'
#  'SUITE 301A' 'C/O AMERICAS SERVICE CO' 'TREASURER  CC 326'
#  'c/o Autozone property tax' 'C/O SCOTT FRANKLIN' 'C/O ROMAN MOROZOV'
#  'C/O RUBEN  JOHNSON  & MORGAN' 'C/O Property Tax Administratio'
#  'C/O CASE ENTERPRISES MGMT' 'c/o IndyMac Federal Bank FSB'
#  'C/O 194-196 BONNER ST' 'C/O VESTA MGMT' 'ATTN THOMAS LUSZCZAK'
#  'C/O TOLLAND GREEN ASSOC' 'C/O KAATZ & PEIKES'
#  'C/O KONOVER OFFICE &INDUSTRIAL' 'C/O FRANCIS  MOEZINIA' '2ND FLR'
#  'ONE AT&T WAY RM 1B201' 'C/O PRESERVATION OF AFFORDABLE'
#  'C/O REAL ESTATE SERVICES' 'c/o HARTFORD CPL CO-OP' 'C/O FIBRO  REALTY'
#  'FL 2' 'c/o Utility Shared Services' 'C/O WESTFORD REAL  ESTATE'
#  'C/O TRINITY COLLEGE BUSINESS' 'C/O HRA REALTY ADVISORS'
#  'c/o LNR PARTNERS LLC' 'C/O KONOVER INVESTMENTS CORP'
#  'C/O CAROLYN JACKSON' 'C/O INTER TOWN REALTY CO'
#  'C/O NUCOR CONSTRUCTION CORPORA' 'C/O WINDSOR MANAGEMENT CO' 'APT 212'
#  'C/O B.P. DISTRIBUTORS INC.' 'C/O ONE SITE SUPPORT SERVICES'
#  'C/O CAPITAL RESTORATION INC' 'C/O DIANE CASSIN' 'C/O OSCAR DEL RISCO'
#  'C/O BERNARDO DIEGO' 'C/O CLYDE BILLINGTON' 'TAX  SERVICES  DEPT'
#  'C/O CAPSTONE PROPERTY SERVICE' 'C/O CONN MORTGAGE INVEST. CORP'
#  'P.O.  BOX 1706' 'c/o Americas Servicing Company' 'UNIT 9D'
#  'C/O WANDA JONES' 'C/O REGO REALTY' 'C/O UNITED CHURCH OF CHRIST'
#  'UNIT T3' 'REAL ESTATE SERV.  RTB1' 'C/O CORNERSTONE'
#  'c/o CoveredBridge Ventures  Ci' 'C/O RICHARD C. JACOBSON  AGT.'
#  'C/O WILLIAM RODRIGUEZ' 'OH 01-27-1802' 'SOVEREIGN BANK'
#  'ATTN:  Mark Keise' 'C/O PARK PROPERTY MGNT' 'ATTN: DOROTHY SHIRLEY'
#  'C/O JAMES RAY ACCOUNTING' '2 FLOOR' 'C/O PROPERTY TAX DEPT 3B'
#  'C/O RELATED COMPANIES  INC' 'C/O INTERTOWN REALTY' 'C/O REV. S.  WEBB'
#  'C/O C H F A FINANCE DEPT.' 'c/o Ruiling L Wei' 'PO BOX 293150' 'APT 3B'
#  'c/o ARCO MGMT CORP.' '26 MILE CREEK RD' 'C/O YORAM BEN-NAIM'
#  'C/O PARK PROPERTY MANAGEMENT C' 'C/O AKBAR AFGHAINE'
#  'C/O MARCONI ENTERPRISES' 'UNIT 4' 'ONE AT & T WAY' 'C/O STAR HARDWARE'
#  'c/o rene Rosado' 'APT 2' 'UNIT 4-i' 'C/O HUME & ASSOCIATES'
#  'c/o Jerome Finn' 'C/O KONOVER OFFICE & INDUST' 'C/O DIAKOMANOLIS  JOHN'
#  'C/O JOHN J. ANTHONY  JR.' 'C/O THE LEADER MORTG CO 339520'
#  'C/O ROBERTO GIANSIRACUSA' 'STE S206' 'C/O DEPT OF PUBLIC WORKS'
#  'c/o SURGICAL CARE AFFILIATES 0' 'C/O HOMESIDE LENDING'
#  'c/o TWO BRICKYARD LANE' 'C/O GE MTG SERVICES' 'C/O ANTONIO BUCCHERI'
#  'c/oCummings&Lockwood LLC Gina' 'ATTN: THOMAS M. LUSZCZAK'
#  'C/O REINER REINER & BENDETT PC' 'c/o Trimont Real Estate Adviso'
#  'RM 36-M-01' 'P.O. BOX 111397' 'C/O HARTFORD FEDERAL C.U.'
#  'C/O ROBERT MICUCCI/AUTOWORLD' '2800 BERLIN TURNPIKE'
#  'C/O MICHAELSON  CONNER AND BOU' 'C/O HOMEEQ' 'SUITE 1105' '29TH FLOOR'
#  'C/O GBD DEVELOPMENT' 'C/O WENDY MOORES' 'C/O LEWIS  AUSTIN  J. TRUSTEE'
#  'C/O CARABETTA MGMT.  CO.' 'C/O JOAN VENDETTI' 'C/O CARLA M BRYANT'
#  'C/O F W WEBB COMPANY' 'C/O THOMAS J PERRA  UNIV. HTFD'
#  'C/O ANTHONY GENUS' 'C/O JS WHITLEY SVC INC' 'c/o Stephen Hesse'
#  'c/o CHRISTOPHER LAMBERT' 'UNIT 103' 'C/O CARMEN SUAREZ'
#  'C/O JOSEPH  CAMPISE' 'c/o Plaza Realty Inc.' 'C/O MASS. ENVELOPE REALTY'
#  'C/O STANLEY WIESEN  INC' 'C/O CARABETTA MGMT CO. ATT; P.'
#  'ATTN: CHRIS MONTEMAYOR' 'c/o Nationstar Mortgage LLC' 'APT A-1 (FRONT)'
#  'UNIT 2A' 'SUITE 106' 'c/o Bally Realty LLC' 'C/O NUTMEG MANAGEMENT'
#  'C/O FRANCIS MOEZINIA' 'UNIT 12D' 'C/O JUDY YOUNG' 'c/o AMENICO CARCHIA'
#  'UNIT 13F' 'APT 10A' 'c/o Joseph Gillespie' 'C/O ICHIBAN  RESTAURANT'
#  'C/O HARTFORD FEDERAL  C. U.' 'C/O C H F A   FINANCE  DEPT.'
#  'C/O NORRIS GRAVES AGENCY' 'C/O JARVIS CORP' 'ATTN: MR. SHAPIRO'
#  'C/O RUBEN  JOHNSON & MORGAN' 'C/O PRESIDENT OF ELDERLY HOUSI'
#  'STATE OFFICE BUILDING' 'ATTN: AURA RIVERA'
#  'C/O NEW COUNTRY MOTOR CAR GROU' 'C/O DEMARTINO FIXTURE CO  INC'
#  'OH4-7126' 'c/o GISELLA MOZZICATO' 'PO BOX 9273'
#  'RE ASSET MANAGEMENT LLC' 'C/O DAVID PAMELEE' 'c/o Barbara Cimiano'
#  'C/O NATL ENTER  ATT D WICK' 'C/O HUD MULTIFAMILY NOTES'
#  'RE ASSET MANAGEMENT  LLC' '975 CORBIN AVENUE APT 17'
#  'C/O CASE ENTERPRISE MGMT' 'C/O WEBSTER BANK'
#  'C/O MASS. ENVELOPE   REALTY' 'APT 22D' 'C/O CVS PHARMACY INC STORE ACC'
#  'C/O 111 OAK ST. ASSOC.' 'C/O JOHN PINONE'
#  'c/o Capstone Property Services' 'c/o Amir D Spears II'
#  'C/O ACCORD VENTURES INC' 'C/O DAVID SEIBMAN' 'C/O PARK ASSOCIATES'
#  'c/o HP Management' 'ATTN: GORDON FULLER  C/O J S W' 'C/O RUSSO BROS.'
#  'C/O PARK PROPERTY MANAGEMENT' 'c/o Countrywide Home Loans Inc'
#  'SUITE 159' '10TH FLR' 'C/O TREASURERS OFFICE'
#  'C/O THE LEADER MORTG CO 236504' 'SUITE 3'
#  'C/O THE HEIGHTS AT AVERY HEIGH' 'c/o Elite Property Management'
#  'c/o Frances Z. Calafiore Esq.' 'C/O AERO ALL GAS COMPANY'
#  'C/O JOHN HINTON' 'SUITE #2' 'C/O ALDOS AUTO REPAIR LLC'
#  'c/o Michelle Shaw' 'C/O PARK  HARDWARE CO.' 'C/O MICHAEL HAIMOFF'
#  'PO BOX 947' 'C/O JAMES D OFSTEIN' 'C/O CARABETTA ATT: P. LAMARINE'
#  'c/o Winstanley Enterprises LLC' 'c/o CHARTER OAK MGMT.'
#  'C/O BARBARA NESS' 'C/O JOHNSIE WALKER' 'C/O EVERHOME MORTGAGE COMPANY'
#  'C/O BES ISRAEL SYNAGOGUE' 'ATTN: DIANE CHAPDELAINE'
#  'c/o GERSTEN CLIFFORD & ROME' 'C/O DEPT OF TRANSPORTATION'
#  'C/O G THOMAS TRONO JR' '1ST FLR' 'ATTN: JAMES  RAY  ACCOUNTING'
#  'C/O O.P.M.' 'C/O FIFTH THIRD BANK' 'UNIT 7-U'
#  'C/O CAPSTONE PROPERTY SERV' 'EQUIFIRST CORPORATION' 'TWO GALLERIA CTR'
#  'C/O DA`REL EASTLING' 'C/O DAWN HENRIQUES' 'C/O CT FURNISS'
#  'C/O SELENE FINANCE' 'c/o OCWEN FEDERAL BANK' 'ATTN: PROEPRTY TAX DEPT'
#  'C/O AMERICAN MASON BUILDING SU' 'C/O SEVERACE FOOD INC'
#  'C/O STEPHEN GASS' 'c/o HomEq Servicing Corporatio'
#  'c/o Sigourney Partners LLC' 'c/o Conn and Conn Co'
#  'c/o Angela R Balfour' 'C/O JOHN J. ANTHONY JR.'
#  'C/O CECIL AUTO  ELECTRIC' 'SUITE 470' 'c/o JEFFREY ZHU'
#  'C/O MINDRAWATEE JAIKISSOON' '140 EAST 45TH ST 18TH FL'
#  'c/o Linda Ferguson' 'UNIT F' 'C/O COONEY SCULLY&DOWLING'
#  'ATTN: ELLEN LAVAGNINO' '#D301' 'C/O CENTRAL CT TEACHERS FCU'
#  'ATTN: JOSEPH P PATTERSON' 'C/O FARM BUREAU ASSOC'
#  'DAS/BUREAU OF PUBLIC WORKS' 'C/O WHITEYS  II'
#  'C/O MICHAELSON  CONNOR & BOUL' 'SUITE 300' 'C/O BRUCE L MORRIS COMM'
#  'C/O HINES SUDDEN SERVICE' 'C/O COMPUVEST MGMT ASSOC.' 'C/O R GOODMAN'
#  'C/O ARISTON FLORIST' 'URB MUNOZ RIVERA' '2800 BERLIN TNPK'
#  'C/O CYNTHIA A CAPOBIANCO CPA' 'C/O C H F A  FINNANCE  DEPT.' 'APT 1427'
#  'C/O SENTINEL BANK' 'UNIT 7D' '3RD FL WEST TOWER' 'C/O BRIAN COURTNEY'
#  'C/O PIPPO DIPAOLA  AGT FOR SER' 'C/O STANLEY REID'
#  'C/O ATTY BARRETT KRASS' 'C/O CT MTG PTNS LTD PTN' 'PO BOX 570-280'
#  'C/O Thomson Tax & Accounting' 'C/O ALLEN SCHAFER' 'C/O ATTY PAUL LEWIS'
#  'C/O SINA INC.' 'C/O JOSE M ROSADO' 'c/o KAY MGMT ASSOCIATES'
#  'ATTN: IMER LAJQI' 'P.O.  BOX  780' 'C/O ATTORNEY JOHN GALE'
#  'C/O CAPSTONE PROPERTY SVC' 'C/O CARABETTA MANAGEMENT CO'
#  'C/O PLAZA  REALTY' 'c/o IMER LAJQU / MAPLE APTS. L' 'C/O GARY P FARACI'
#  'C/O NORMAN GAHM' 'C/O REAL  ESTATE SERVICES' 'c/o JOHN IAFRANCESCO'
#  'C/O LISBON FURNITURE CO' 'C/O COUSIN' 'C/O CHESS MANAGEMENT  LLC'
#  'C/O MELVILLE CHARITABLE TRUST' 'c/o Chase Home Finance LLC'
#  'c/o WALDRON MINTO' 'C/O COMMON GROUND' 'C/O JUDY SCHARTZ LEVY TR.'
#  'C/O YOUNG B HUH' 'C/O ICARE MANAGEMENT' 'C/O FATIMA SQUARE'
#  'c/o COUNTRYWIDE' 'C/O CT. HOUSING INVESTMENT FUN' 'C/O MR ROB KOFF'
#  'UNIT 1E' 'C/O CHASE HOME FINANCE LLC' 'C/O THE LEADER MORTG CO 236577'
#  'C/O MORRIS CANTER' 'c/o Sharon Allen' 'c/o Venture Properties LLC'
#  'UNIT 402' 'C/O RUBENSTEIN & SENDY LLC' '1 UNIVERSITY PL    APT 9D'
#  'SUITE 403' 'c/o Casle Corporation' 'c/o Prospect Enterprises'
#  'C/O THE WINDSOR MANAGEMENT CO' 'c/o The McCue Mortgage Company'
#  'ATTN: JAMES RAY ACCOUNTING' 'C/O PARAGON MGMT GP LLC'
#  'C/O LOUIS FRANKLIN' 'C/O CONTIMORTGAGE CORPORATION' 'APT 2E'
#  'c/o Michaelson  Conner and Bou' 'APT 5C' 'C/O DEAN VLECIDES'
#  'C/O WINN RESIDENTIAL' '909 CHESTNUT  RM 36-M-1' 'P.O.BOX 628'
#  'UNIT 4C-43' 'c/o DAVID BASS MD' 'C/O MAXIM POWER CORP' '#205'
#  'C/O RICHARD L ZAYAS' 'C/O CATARINA MORA' 'UNIT 7E'
#  'c/o Select Portfolio Servicing' 'C/O COMMUNITY RENEWAL TEAM'
#  'C/O KAREN ADDISON' 'c/o Meadows Real Estate Manage'
#  'C/O KONOVER RESIDENTIAL CORP' 'c/o DAVID S. FRANKEL ESQ.'
#  'c/o Family Dollar Lease Admini' 'CALLE CAMPO BELLO 18'
#  'C/O WOLDEY OHAMMES' 'C/O MICHAEL COHEN' 'c/o Carmine Gugliotti'
#  'C/O G. THOMAS TRONO JR' 'C/O Option One Mortgage Corp.'
#  'C/O ANDREW LERNER' 'C/O ROBERT WEINSTEIN'
#  'c/o Equity Property Tax Group' 'c/o Susan B Nobleman'
#  'c/o Triad Real Estate Services' 'C/O SELENE FINANCE LP'
#  'c/o Gergory Funding LLC' 'c/o REO DEPARTMENT' 'C/O BOB WEINSTEIN'
#  'c/o Wilshire Credit Corporatio' 'c/oRushmore Loan Management Se'
#  'MS-PTX-C-35' 'C/O NATIONSTAR MORT LLC' 'C/O COMMUNITY SOLUTIONS'
#  'ATTN M J NEIDITZ' 'c/o Statewide Property Managem'
#  'C/O PLIMPTON & HILLS' 'c/o Saxon Mortgage Services'
#  'C/O MOHAN RAMPERTAB' 'C/O FREED MARCRAFT' 'UNIT 315' '5TH FL'
#  'c/o MORRIS CANTER' '#404' 'C/O BAC HOME LOANS SERVICING L'
#  'THE FORUM SUITE 402' 'C/O MARJORIE MORRISSEY'
#  'c/o Ocwen Loan Servicing LLC' 'c/o YVELISSE GOMEZ'
#  'C/O JACQUELINE MARTINEZ' 'c/o Frederick A Beardsley' '25TH FLOOR'
#  'c/o Maria Martinez - Leasing O' 'ATTN:  TERESA PREZIOSI'
#  'c/o Melrose John' 'c/o Wilmington Saving Fund Soc' 'C/O IMAGINEERS INC'
#  'C/O HOUSING CONSULTANTS' 'c/o THE CIARCIA FAMILY TRUST'
#  'c/oMutual Housing Assoc of Gre' 'c/o IMAGINEERS INC'
#  'C/O MILLENNIUM REAL ESTATE' 'TAX DEPT' 'ATTN: PM DEPT #0763'
#  'c/o Cantor Real Estate LP' 'c/o The Schochet Companies'
#  'c/o Americas Servicing Co' 'c/o Dean Vlecides'
#  'C/O SHELDON OAK CENTRAL INC' 'C/O SHAWN ADAMS' 'c/o william LaPlant'
#  'C/O John T Forrest' 'C/O PROSPECT ENTERPRISES  LLC'
#  'c/o Paradigm Asylum LLC' 'C/O PROPERTY MAX'
#  'c/o Office of the General Coun' 'c/o HENRY WINIARSKI ESQ.'
#  'C/O ACCOUNTING' 'c/o Bruce G. Temkin Esq.' 'c/o  M & T Bank'
#  'C/O ALAN SCHUMAN' 'WING C - SUITE 110' 'c/o BCI'
#  'C/O ALTUS GROUP US INC # 7541' 'c/o McCue Mortgage Company'
#  'c/o Hunt Leibert Jacobson' 'C/O SCHOCHET CO' 'c/o Select Portfolio'
#  'c/o Richard Logozzo' 'THE MARCUS LAW FIRM' 'c/o Caliber Home Loans'
#  'PO BOX 85400' 'c/o Information Systems Networ' 'c/o Irena Rafatpanah'
#  'C/O SHARON DAWN ALLEN' 'ATTN: CORP REAL ESTATE' '200 PRATT ST'
#  'SUITE #6' 'C/O JR GILLETT REALTY CORP' 'C/O PLIMPTON HILLS' 'APT 607'
#  'C/O APEX REAL ESTATE MGMT LLC' 'c/o Ditech Financial LLC' 'c/o ISN'
#  'c/o Eastern Savings Bank' 'PO BOX 280242' 'C/O FABRIZI JOSEPH'
#  'C/O JOHN FORREST' 'c/o McDonald`s Corporation' 'C/O JAMES CARTER'
#  '2 GALLERIA TOWER SUITE 950' 'c/o Housing Consultants LLC'
#  'C/O CITIWEST PROPERTIES' 'c/o Kiril Ratia' 'OH- 01-10-0930'
#  'c/o The Mccue Mortgage Co.' 'C/O CITIWEST' 'c/o Detech Financial LLC'
#  'c/o WMR' 'c/o FIGURE EIGHT PROPERTIES' 'C/O OCWEN LOAN SERVICING'
#  'C/O MICHAEL BURDO' 'C/O SHOCHET COMPANIES' 'C/O SCHOCHET COMPANIES'
#  'UNIT 2203' 'BANK OF AMERICA NC1-001-03-81'
#  'C/O ANTOINETTE HAMBLIN KEATON' 'SUITE 201' 'c/o Mark Irving'
#  'C/O  TRAMMELL CROW  CO.' 'C/O HAZEL GREY' 'C/O DANA WRIGHT'
#  'C/O RICHARD  JACOBSON  AGT.' 'PO BOX 370495' 'UNIT B' 'UNIT 820'
#  'C/O CHRISTOPHER ROBERTS' 'C/O  DAN  SOUZA' 'C O FRONTIER COMMUNICATIONS'
#  'C/O SOUZA &SONS' 'c/o Fay Servicing' 'C/O LOUISE KAUFMAN' 'C/O SHAW'
#  'Shellpoint Mortgage servicing' 'C/O PROSPECT ENETERPRISES  LLC'
#  'C/O RESIDENTIAL CAPITAL MGMT' 'C/O VISCO ASSOC.' 'C/O YRELISSE A GOMEZ'
#  'QUEST DIAGNOSTIS INC  CV-3105' 'C/O WILSHIRE' 'C/O REGO MGMT'
#  'C/O BARBARA LAWRENCE' 'c/o New Penn Financial LLC' 'C/O DANNY RHODES'
#  'C/O J R CODY' 'C/O J.R. CODY' 'CO CHARLLES VENDETTI' 'C/O REMAX'
#  'C/O HOUSING CONSULTATS' 'C/O JOHN ZIOBRO' 'c/o DCB Law Group LLC'
#  'C/O CARTER MARIO' 'c/o Albana Gallari & Dritan Ga' 'C/O KOPCHA'
#  'c/o WHITE AND KATZMAN MGMT' 'C/O GISELLE MOZZICATO'
#  'C/O MAHASHWER BEHARRY  MEMBER' 'C/O CHRIS DALLAS'
#  'C/O ING INVESTMENT MANAGEMENT' 'C/O MARJORIE E MORRISSEY'
#  'c/o LITTON LOAN SERVICING' 'PTA -EX#8684'
#  'C/O EQUICREDIT CORP OF AMERICA' 'C/O AHOLD FINANCIAL SERVICES'
#  'C/O SAVINGS INSTITUTE BANK TRU' 'C/O WHITE & KATZMAN MANAGEMENT'
#  'SIMONS REAL ESTATE GROUP INC' 'PERSONAL BOX 691'
#  'HOUSING I CORP c/o CARABETTA M' 'C/O RAMA REALTY'
#  'c/o CT Properties Inc' 'c/o Ronald Peikes' 'C/O MOON BAKERY INC'
#  'c/o Greenwich Hospitality Grou' 'C/O REGO REALTY CORP'
#  'C/O MARY LYNN DIMAGGIO' 'C/O CDJ AUTO ELECTRIC' 'c/o JOSEPH D. DIMAURO'
#  'C/O GAMUT REALTY' 'AT & T MOBILITY LLC' 'C/O INTERTOWN REALTY CO. LLC'
#  'C/O DANA VIENT NORTHEAST RETAI' 'C/O LULDES ORTIZ'
#  'c/o CT Properties LLC' 'C/O KELLY BIGGINS' 'C/O THE DAVIS COMPANIES'
#  'C/O  SGHRMC' 'C/O BANK OF AMERICA' 'C/O DEMARCO MGMT CORP'
#  'c/o Caliber home Loans Inc' 'c/o Carrington Mortgage Servic'
#  'c/o Gregory Norsigian' 'C/O  GMAC ATT  TINA  CUMMINGS'
#  'C/O  FIRST  &  LAST TAVERN' 'ATTN: PROPERTY TAX DEPT'
#  'C/O OCWEN LOAN SERVICING  LLC' 'PSC 477 BOX 32' 'C/O TRACIAN ROWE'
#  'c/o Joyce J. Ford' 'c/o Maydena Webster' 'c/o Caliber Home Loans Inc'
#  'c/o McCalla raymer' 'c/o HIGHLAND MANAGEMENT' 'c/o Michael Burdo'
#  'C/O NEUROSURGEONS OF CENTRAL C' 'c/o C T CORPORATION SYSTEM'
#  'ATTN: CORPORATE REAL ESTATE TA' 'C T CORPORATION SYSTEM'
#  'c/o MGA Capital LLC' 'C/O ALAN ROSENBERG' 'C/O JENNIFER SABIN'
#  '141-143 CAPEN ST' '99 PRATT ST' '111 PEARL ST' '606 FARMINGTON AVE'
#  '7276 FRANKLIN AVE' 'CONGRESS ST' 'PO BOX260338' '#2' '25 CAPITOL AVE'
#  '172 OAKWOOD DR  1' '3RD FLOOR' '80 CEDAR ST' 'STE 504'
#  '172 OAKWOOD DR.  1' '1050 SULLIVAN AVENUE' '555 DAY HILL RD' 'UNIT A1'
#  '16 CHARTER OAK PL UNIT C' 'PO BOX 231321' '110 MOUNTAIN RD'
#  '24 PARK TERRACE' '111 ROBERTS ST  G-1' '421 WETHERSFIELD AVE'
#  '151 NEW PARK AVE  BOX 55' '160 FAIRFIELD AVE' '58 CAPITOL AVE'
#  '49 GILBERT AV' 'PO BOX 400398' '365 MAIN ST' 'ONE CONSTITUTION PLAZA'
#  'STE 105' '74 BATTERSON PARK RD' '84 COACH RD' '363 MAIN ST' 'SUITE 301'
#  '600 PEACH TREAT ST' 'PO BOX 1933' '1N' '21 GRIEG RD' '68 SOUTH MAIN ST'
#  'PO BOX 260338' '150 SULLIVAN AVE' '48 FOREST ST' 'UNIT 5'
#  'PO BOX 230736' 'C/O STRATFORD ASSOCIATES' '111 ROBERTS ST G-1'
#  'PO BOX 330487' '119 BLUE RIDGE DR']
# Number of unique values in MAIL_ADDR2: 772
#
# Values in CITY:
# ['HARTFORD' 'DEBARY' 'SOUTH WINDSOR' 'NEWINGTON' 'MILTON' 'JAMAICA'
#  'STAMFORD' 'WINDSOR' 'WEST HARTFORD' 'BETHANY' 'EAST HARTFORD' 'AYER'
#  'FARMINGTON' 'BLOOMFIELD' 'KILLINGWORTH' 'WETHERSFIELD' 'ESSEX'
#  'NEW BRITAIN' 'W HARTFORD' 'EVANSVILLE' 'GLASTONBURY' 'NEW HARTFORD'
#  'BERLIN' 'SOUTHINGTON' 'ROGERS' 'DECATUR' 'BROOKLYN' 'CARROLLTON'
#  'HOUSTON' 'CHESHIRE' 'LANESBORO' 'CHARLOTTE' 'CHICAGO' 'FLUSHING'
#  'TOLLAND' 'GLEN BURNIE' 'DALLAS' 'ARLINGTON' 'VALLEY STREAM' 'CAMBRIDGE'
#  'LONGMEADOW' 'TUCSON' 'BRANFORD' 'IRVINE' 'FAIRFIELD' 'BRISTOL'
#  'SAN DIEGO' 'VERNON' 'KEY BISCAYNE' 'BOSTON' nan 'CRANSTON' 'MANCHESTER'
#  'TARIFFVILLE' 'NAUGATUCK' 'FORT WORTH' 'MUNCIE' 'STORRS' 'CROMWELL'
#  'DENVER' 'ROANOKE' 'WOONSOCKET' 'GOSHEN' 'NORTHFORD' 'OLD SAYBROOK'
#  'LEBANON' 'PORT CHARLOTTE' 'NEW YORK' 'MESA' 'PLANO' 'WATERBURY'
#  'PHILADELPHIA' 'GROTON' 'BIRMINGHAM' 'CANTON' 'NIXA' 'MERRIMACK'
#  'UPPER MARLBORO' 'POMPANO BEACH' 'GOTHA' 'BOGOTA' 'MENLO PARK' 'COLUMBIA'
#  'STRATFORD' 'WESTBROOK' 'ESCONDIDO' 'ELLINGTON' 'AVON' 'GRANBY' 'HAMDEN'
#  'WESTFIELD' 'ENFIELD' 'GREENWICH' 'KENNESAW' 'EAST BERLIN' 'STURBRIDGE'
#  'BURLINGTON' 'WEST MYSTIC' 'KENSINGTON' 'ROCKY HILL' 'SOUTHBURY'
#  'Toronto Ontario' 'HOLLYWOOD' 'TRUMBULL' 'COLLEGEVILLE' 'SIOUX FALLS'
#  'BRONX' 'WEST' 'COLUMBUS' 'BOTHELL' 'NORTH HAVEN' 'SANTA ROSA'
#  'WATERFORD' 'MOUNT VERNON' 'INVERNESS' 'BAYSIDE' 'ST LOUIS' 'WATERTOWN'
#  'LAWRENCEVILLE' 'AMSTON' 'SOUTH GLASTONBURY' 'DANBURY' 'MIDDLETOWN'
#  'NEW HAVEN' 'COLORADO SPRINGS' 'VERNON ROCKVILLE' 'OAKLAND PARK'
#  'ASBURY PARK' 'ONTARIO' 'ATLANTA' 'WEST PALM BEACH' 'CORAL SPRINGS'
#  'POUND RIDGE' 'PAWTUCKET' 'GWYNN OAK' 'LITCHFIELD' 'BROOKLINE'
#  'HALLANDALE BEACH' 'LAUREL' 'WEST SIMSBURY' 'TERRYVILLE' 'OLD LYME'
#  'HEWLETT' 'WINDSOR LOCKS' 'MIDLOTHIAN' 'SANTA CRUZ' 'WINNIPEG'
#  'PHOENIXVILLE' 'WESTBURY' 'NAPA' 'PITTSFORD' 'EAST GRANBY' 'HACKENSACK'
#  'EAST HADDAM' 'EAST ELMHURST' 'MIAMI' 'CENTEREACH' 'POMFRET CENTER'
#  'CHESTER' 'COLCHESTER' 'GUAYNABO' 'DARIEN' 'HIGGANUM' 'SEYMOUR'
#  'WILLIMANTIC' 'WEST HAVEN' 'LAKE WORTH' 'WALLINGFORD' 'RICHMOND'
#  'JUPITER' 'FREDERICK' 'MARLBOROUGH' 'ORANGE' 'WHITE PLAINS' 'AIRMONT'
#  'MANSFIELD CENTER' 'COVINA' 'MONROE' 'BASKING RIDGE' 'BOLTON'
#  'VIRGINIA BEACH' 'YORK' 'BRONXVILLE' 'DANDURY' 'O FALLON' 'SUFFIELD'
#  'CUTHBERT' 'EAST WINDSOR' 'BROAD BROOK' 'SAN FRANCISCO' 'AGAWAM'
#  'MERIDEN' 'NEW CANAAN' 'PARK FOREST' 'TROY' 'SUITLAND' 'SOUTH ORANGE'
#  'CAPE CORAL' 'NIANTIC' 'SPRINGFIELD' 'ALBANY' 'DEPEW' 'NEW LONDON'
#  'SHERMAN OAKS' 'WINNSBORO' 'SPRING VALLEY' 'BATON ROUGE' 'HOLYOKE'
#  'CLEARWATER' 'N MIAMI BEACH' 'MENDOTA HEIGHT' 'KINGS POINT' 'KISSIMMEE'
#  'YONKERS' 'FT WORTH' 'LAWRENCE' 'DELRAY BEACH' 'PORT ST LUCIE'
#  'EAST WINDSOR CT' 'DOWNEY' 'DORCHESTER' 'FAR ROCKAWAY' 'FT LAUDERDALE'
#  'GLASTONBUBY' 'EAST HAMPTON' 'ELMONT' 'SIMSBURY' 'HOBOKEN' 'MISSOUR CITY'
#  'SOUTH' 'ALAMO' 'WOBURN' 'WOODBRIDGE' 'PLANTSVILLE' 'LUDLOW' 'ANDOVER'
#  'CHESTNUT RIDGE' 'BELOIT' 'NEPONSIT' 'CUMBERLAND' 'WINDSOR ST' 'FRANCE'
#  'MARION' 'MOUNT DORA' 'WESTMINSTER' 'JEFFERSON' 'PAWCATUCK'
#  'EAST PROVIDENCE' 'SAINT LOUIS' 'LAKEWOOD' 'EASTON' 'MEDFIELD'
#  'RICHMOND HILL' 'MIAMI BEACH' 'WESTPORT' 'EDGEWATER' 'PLAINVILLE'
#  'SOUTH LANCASTER' 'RANDALLSTOWN' 'SEWELL' 'GREAT NECK' 'FAYETTEVILLE'
#  'KATY' 'EGG HARBOR TOWNSHIP' 'TEMPE' 'MONSEY' 'MONTGOMERY'
#  'MOUNTAIN VIEW' 'OKLAHOMA CITY' 'MIDDLE VILLAGE' 'PORTLAND' 'NANUET'
#  'PLEASANT VALLEY' 'BREWSTER' 'EAST HARTLAND' 'QUINCY' 'KEW GARDENS'
#  'AKRON' 'BONITA SPRINGS' 'NEEDHAM' 'OWENSBORO' 'NEW HYDE PARK'
#  'CEDARHURST' 'COVENTRY' 'SUN CITY' 'WILTON' 'HAMPTON' 'NEW GLOUCESTER'
#  'SHARON' 'FORT MILL' 'MASPETH' 'CLIFTON' 'GAINESVILLE' 'LAURELTON'
#  'BOYNTON BEACH' 'JERSEY CITY' 'WILLINGTON' 'FT. MILL' 'MADISON' 'MEMPHIS'
#  'ORMOND BEACH' 'GREENSBORO' 'MIDDLE HADDAM' 'PHOENIX'
#  'HASTINGS-ON-HUDSON' 'CORONA' 'GREAT BARRINGTON' 'PASADENA' 'WEATOGUE'
#  'ESTERO' 'HOPKINS SC' 'PEEKSKILL' 'MILFORD' 'REVERE' 'SALT LAKE CITY'
#  'GREER' 'UNIONDALE' 'GUILFORD' 'NORTH FRANKLIN' 'LONG BEACH'
#  'MOUNT KISCO' 'SPANISH FORK' 'BEDMINSTER' 'SARASOTA' 'MONSON'
#  'BRIDGEPORT' 'DES MOINES' 'ELLICOTT CITY' 'NEW ROCHELLE' 'NOVI'
#  'MEREDITH' 'TORRINGTON' 'FARMINGTOM' 'MALDEN' 'BAY HARBOR ISLANDS'
#  'GOLDENS BRIDGE' 'UNIONVILLE' 'MANHASSET' 'EGG HARBOR TWP' 'BLOOM FIELD'
#  'MOHEGAN LAKE' 'SUMMERLAND KEY' 'CORAL GABLES' 'PITTSFIELD' 'RIVERDALE'
#  'ARMONK' 'READING' 'AMHERST' 'PARSIPPANY' 'LAS VEGAS' 'WEST SUFFIELD'
#  'NORWALK' 'LEWISVILLE' 'HYDE PARK' 'WASHINGTON' 'EAST HAVEN' 'MIRAMAR'
#  'SAN ANTONIO' 'GLENDALE' 'JACKSONVILLE' 'WILMINGTON' 'TAMPA' 'ENGLEWOOD'
#  'WINSTED' 'SILVER SPRING' 'WEST BRIDGEWATER' 'HOLLIS' 'CRANFORD'
#  'SCOTTSBLUFF' 'GRANDBY' 'NONVET' 'ROCKVILLE' 'HIGHLAND PARK'
#  'SAUNDERSTOWN' 'SIMI VALLEY' 'BUFFALO' 'GLASTON BURY' 'WESTON'
#  'CLEVELAND' 'WAPPINGERS FL' 'MARCO ISLAND' 'FORT MYERS' 'SAN LEANDRO'
#  'SHELTON' 'MIDDLEFIELD' 'BELMONT' 'UNION' 'FRAMINGHAM' 'SUFFERN'
#  'CANTERBURY' 'VISALIA' 'AVON06001' 'GILBERT' 'SAINT ALBANS' 'AUSTIN'
#  'MC LEAN' 'E.HARTFORD' 'PASSAIC' 'NOVATO' 'CENTREVILLE' 'REGO PARK'
#  'SOUTHBRIDGE' 'MELVILLE' 'EAST ATLANTIC BEACH' 'WETHERSFIELD CT'
#  'LINDENHURST' 'MIDLAND PARK' 'GLEN HEAD' 'SALEM' 'WEST SPRINGFIELD'
#  'TRENTON' 'PLANTATION' 'CHAPEL HILL' 'BEDFORD' 'RIDGEWOOD' 'SCOTTSDALE'
#  'PERRINEVILLE' 'PEABODY' 'QUEENS VILLAGE' 'WESTERVILLE' 'NORFOLK'
#  'WALLKILL' 'WEST MIAMI' 'NORTH' 'WORCESTER' 'BLOOMIELD' 'NAPLES'
#  'WALTHAM' 'LOGANVILLE' 'NORTON' 'OZONE PARK' 'WEST NYACK' 'TEANECK'
#  'ORLEANS' 'TORONTO ONTARIO' 'CARMEL' 'TENAFLY' 'NATICK' 'CHICOPEE'
#  'EUGENE' 'HACKETTSTOWN' 'NEWTON' 'EASTFORD' 'HUNTINGTON VALLEY'
#  'SOUTHLAKE' 'CHERRY HILL' 'SMYRNA' 'WOLCOTT' 'BLOOMFEILD' 'LARCHMONT'
#  'ARCADIA' 'LAND O LAKES' 'LAGUNA HILLS' 'WHITESTONE' 'VACAVILLE'
#  'RANDOLPH' 'FORT WASHINGTON' 'JERICHO' 'ALEXANDRIA' 'NEW PALTZ'
#  'SANTA ANA' 'LOS ANGELES' 'MILLER PLACE' 'SHORT HILLS' 'TALLMAN'
#  'WALPOLE' 'Wethersfield' 'ROYAL PALM BEACH' 'MANSFIELD' 'E HARTFORD'
#  'CONYERS' 'SIMPSONVILLE' 'WOODSIDE' 'SARATOGA SPRINGS' 'MEDLEY'
#  'OAK BROOK' 'WILLISTON PARK' 'SAN JOSE' 'MIROMAR LAKES' 'AUBURNDALE'
#  'MEDIA' 'PARKSLEY' 'HADDAM' 'GENEVA' 'NEW JERSEY CITY' 'MELBOURNE BEACH'
#  'MCDONOUGH' 'ROCHESTER' 'NORTHBOROUGH' 'MERIDAN' 'ITHACA' 'HORSHAM'
#  'RIVIERA BEACH' 'PITTSBURGH' 'YPSILANTI' 'COLLEGE PARK' 'BROOKFIELD'
#  'MOORPAK' 'FAIRFAX' 'GREENVILLE' 'WEST LEBANON' 'BYRON'
#  'EAST BRIDGEWATER' 'HADLEY' 'FREEPORT' 'BROOLYN' 'NEWPORT' 'BAYONNE'
#  'KENSINGTON LONDON' 'FARMINGDALE' 'DESMOINES' 'ANDERSON' 'STONE MOUNTAIN'
#  'CONCORD' 'WINTER HAVEN' 'PLYMOUTH' 'COCONUT CREEK' 'ALPHARETTA'
#  'TOMS RIVER' 'SOUTH SALEM' 'HOPEWELL JUNCTION' 'MINEOLA' 'DURHAM'
#  'RIDGEFIELD' 'BALTIMORE' 'IRVING' 'WEYMOUTH' 'HAWARDEN' 'CINCINNATI'
#  'hartford' 'PEMBROKE' 'ELLAVILLE' 'ST ALBANS' 'SOUTH BOSTON' 'RALEIGH'
#  'SACO' 'SOMERS' 'BOCA RATON' 'PLAINTSVILLE' 'ASTORIA' 'ROSEDALE' 'DOVER'
#  'BRAINTREE' 'HEBRON' 'STAFFORD SPRINGS' 'TAYLORS' 'NEWYORK'
#  'FRANKLIN PARK' 'FORESTVILLE' 'MIAMISBURG' 'PROSPECT' 'PEWAUKEE' 'NEWARK'
#  'FORT LAUDERDALE' 'LONG MEADOW' 'WESTWOOD' 'DERBY' 'ST. AUGUSTINE'
#  'WARWICK' 'PEMBROKE PINES' 'HARWINTON' 'WEST GRENNWICH' 'BETHEL'
#  'EAST GLASTONBURY' 'SOMERVILLE' 'NORTHFIELD' 'WINDHAM' 'DEERFIELD'
#  'PENSACOLA' 'HEADLAND' 'MINNETONKA' 'SHARPS CHAPEL' 'MOBILE' 'KEY WEST'
#  'WATERLOO' 'PALM COAST' 'HYATTSVILLE' 'WEST HARRISON' 'BELLEMEAD'
#  'ISLIP TERRACE' 'SEATTLE' 'BETHESDA' 'BRIARWOOD' 'WAPPINGER FALLS'
#  'TORRINGOTN' 'ANNAPOLIS' 'CHINO HILLS' 'WHITESTON' 'DIAMOND POINT'
#  'BETTENDORF' 'NEWFIELD' 'JUANA DIAZ' 'GREENFIELD' 'MORRISTOWN' 'RIVERTON'
#  'CONENTRY CLUB' 'METHUEN' 'AMITYVILLE' 'WINDSOR CT' 'CHAPPAQUA'
#  'MOORPARK' 'ELDORADO' 'BALDWIN' 'BROOMFIELD' 'HATBORO' 'AWENDAW'
#  'NORTH GRANBY' 'HOLMDEL' 'PALM BAY' 'EWING' 'FAIR LAWN' 'FREMONT'
#  'CALGARY' 'WEST PARK' 'COLLEGE POINT' 'KINGSTON' 'BRITOL' 'POCOMOKE CITY'
#  'BECKET' 'CUTLER BAY' 'HOBE SOUND' 'IRVINGTON' 'LAGUNA BEACH' 'OAKDALE'
#  'BLOOMFIELD CT' 'ELLENWOOD' 'KINGSLAND' 'MT LAUREL' 'ELMHURST' 'MYSTIC'
#  'SUNNYSIDE' 'WEST ORANGE' 'OKLAHOMA' 'PLAINVIEW' 'GREENS FARMS'
#  'West HARTFORD' 'LUQUILLO' 'PROVIDENCE' 'HARFTFORD' 'ST.PETERSBURG'
#  'ULSTER PARK' 'PONCE' 'PALM BEACH GARDEN' 'SAVANNAH' 'REDDING' 'HOPEWELL'
#  'MCLEAN' 'COPPELL' 'GUANICA' 'KILLINWORTH' 'EL SEGUNDO' 'W.HARTFORD'
#  'CARROLTON' 'LITTLETON' 'MENDOTA HEIGHTS' 'NORWICH' 'CENTENNIAL'
#  'GOLDEN BRIDGE' 'CLINTON' 'PEESKILL' 'SUDBURY' 'PURCHASE' 'LENOX'
#  'PITTSBURG' 'TOANO' 'COEUR D ALENE' 'LAFAYETTE' 'FARMINGTOM CT'
#  'JAMAICA ESTATES' 'PALM BEY' 'FRESH MEADOWS' 'KEENE' 'HIGHLANDS RANCH'
#  'BRANDON' 'HARTFORD CT' 'ROCKLIN' 'OLD BROOKVILLE' 'OAKLAHOMA CITY'
#  'VENICE' 'MONTEBELLO' 'MOODUS' 'BEAVERTON' 'BOULDER' 'TAFTVILLE'
#  'TITUSVILLE' 'CHEEKTOWAGO' 'WOODMERE' 'ODESSA' 'MEDFORD' 'SCARDALE'
#  'CAPECORAL' 'LISLE' 'SCARSDALE' 'PORT CHESTER' 'FOREST HILLS' 'WYCKOFF'
#  'VINEYARD HAVEN' 'FT MILL' 'CHESTNUT HILL' 'RENO' 'SAVOY' 'SAN DIENGO'
#  'EAST LONGMEADOW' 'PLANTVILLE' 'OAKLAND GARDEN' 'COPIAGUE' 'NEWBRITAIN'
#  'GOODLAND' 'OLD ORCHARD BEACH' 'SOUTH RICHMOND HILL' 'OVERLAND PARK'
#  'BARKHAMSTED' 'BOYTON BEACH' 'CAMP HILL' 'SANTA' 'FARMINGTON CT'
#  'STERLING' 'BIG INDIAN' 'ADELPHI' 'CLERMONT' 'EAST GREENWICH' 'W HARTFO'
#  'DENNIS' 'BARDONIA' 'NEWTON FALLS' 'MOORESVILLE' 'ALAMEDA'
#  'NORTH BRANFORD' 'EAST HATFORD' 'CHRISTIANSTED' 'O` FALLON' 'BLOOKLYN'
#  'WAYNE' 'BRENTWOOD' 'FLORAL PARK' 'CARLISLE' 'OSSINING' 'ELMSFORD'
#  'TANPA' 'HUNT VALLEY' 'WOODLAND HILLS' 'STUART' 'ROCKVILLE CENTER'
#  'SHREWSBURY' 'COLCESTER' 'ROSELAND' 'JAMAICA ESTATE' 'PRORIA' 'HARFTORD'
#  'LOVELAND' 'WAYCKOFF' 'ORLANDO' 'SECAUCUS' 'BOWIE' 'CLARKSBURG' 'HARFORD'
#  'ROSLYN HEIGHTS' 'LUTZ' 'LOWELL' 'SHESTER' 'EAST STROUDSBURG' 'CROWMELL'
#  'FRESH MEADOW' 'Windsor' 'LANGWOOD' 'TORONTO ON M5M2W5' 'PORT JERVIS'
#  'BRIDGEWATER' 'BONIFAY' 'LIVERMORE' 'TULSA' 'PALO ALTO' 'TACOMA' 'PEORIA'
#  'SAINT PAUL' 'VALLEY STEAM' 'MECHANICSVILLE' 'WILLINGBORO' 'IVORYTON'
#  'EAST GRANY' 'SOUTHPORT' 'SPRING CITY' 'REDONDO BEACH' 'LAKE FOREST'
#  'ASHFORD' 'MAMARONECK' 'LYNBROOK' 'NEW CITY' 'ROCKAWAY' 'ANAHEIM'
#  'STATEN ISLAND' 'Hartford' 'NORTH BETHESDA' 'WSET HARTFORD'
#  'ROCKVILLE  CENTER' 'SALT LAKE' 'HANOVER' 'CASTANEDA' 'HARTFOD' 'Queens'
#  'NORTH CHARLESTON' 'FPO' 'Bristol' 'STOCKTON' 'Bloomfield' 'HARTFROD'
#  'EDISON' 'Rocky Hill' 'EASTCHESTER' 'ALBERTSON' 'NEW BRITAIN AVE'
#  'NASHUA' 'East Hartford' 'CHAPLIN' 'FAIR OAKS' 'EL MIRAGE' 'DELAND'
#  'SOUTH HOUSTON' 'CONSHOHOCKEN' 'LAKE ZURICH' 'GLOUCESTER' 'ROCKCY HILL'
#  'CHESTER RIDGE' 'SAN RAMON' 'CEDAR HILL' 'MANCHERTSER' 'APEX'
#  'UNION CITY' 'Chestnut Ridge' 'LYNNBROOK' 'LAKE ELSINORE' 'BURBANK'
#  'WETHERSFIELD AV' 'CARLSBAD' '06114' 'W. NASHVILLE' 'Coppell' 'ST PAUL'
#  'SANDY SPRINGS' 'BLOOMFILED' 'CAMBRIA HEIGHTS' 'SINCLAIR' 'MATIAK'
#  'Hackensack' 'CEDAR RAPIDS' 'Westport' 'CARLTON' 'Wallingford' 'KIRKLAND'
#  'HARRISBURG' 'GRANDVILLE' 'FORT LAUDERALE' 'Port St Lucie' 'WINCHESTER'
#  'CLAREMONT' 'ST CLOUD' 'NEWINGTON AV' 'NEW BRITIAN' 'FORT PIERCE'
#  'South Windsor' 'FARMMINGTON' 'WESTERLY' 'GREENICH' 'WESTBOROUGH']
# Number of unique values in CITY: 863
#
# Values in STATE:
# ['CT' 'FL' 'NY' 'MA' 'IN' 'AR' 'GA' 'TX' 'NC' 'IL' 'MD' 'VA' 'AZ' 'CA'
#  'RI' 'CO' 'PA' 'AL' 'MO' 'NH' 'NJ' 'SD' 'IA' 'OH' 'WA' 'MB' 'PR' nan 'MI'
#  'SC' 'LA' 'MN' 'TN' 'WI' 'OK' 'ME' 'KY' 'UT' 'NV' 'DC' 'DE' 'NE' 'CN'
#  'OR' 'UK' 'KS' 'ID' 'VI' 'NU' 'M' 'AP' 'ct' 'ny' 'US' 'ST' 'FC']
# Number of unique values in STATE: 55
#
# Values in PROP_LOC_NUM:
# ['303' '809' '156' ... '323-341' '1860' '13-15']
# Number of unique values in PROP_LOC_NUM: 1584
#
# Values in PROP_LOC_NAME:
# ['BELLEVUE ST' 'NEW BRITAIN AV' 'RUSS ST' ... 'F.D. OATES AVE'
#  'HENDRICXSEN AVE' 'VAN DYKE AVE']
# Number of unique values in PROP_LOC_NAME: 3995
#
# Values in LIEN_SOLD:
# [nan 'Y']
# Number of unique values in LIEN_SOLD: 1

# %% [markdown]
# ### cross tabulation TAX_DUE across the STATE column

# %%
pd.crosstab(["TAX_DUE"],df["STATE"],margins=True)
# Out:
# STATE    AL  AP  AR   AZ   CA  CN   CO      CT  DC  DE  ...  UK  US  UT   VA  \
# row_0                                                   ...
# TAX_DUE  28   1   7  102  392  14  103  122033  27  36  ...   6   1  43  144
# All      28   1   7  102  392  14  103  122033  27  36  ...   6   1  43  144
#
# STATE    VI  WA  WI  ct  ny     All
# row_0
# TAX_DUE   3   6  27   2   1  136010
# All       3   6  27   2   1  136010
#
# [2 rows x 56 columns]

# %% [markdown]
# * #### The dataset contains records for 56 unique states or regions.
# * #### The All row gives the total count of records for each state (which is identical to the counts in the TAX_DUE row, implying that every record in the dataset has taxes due).
# * #### For example:
# #### AL (Alabama): 28 records, all with taxes due.
# #### CT (Connecticut): 122,033 records, all with taxes due.
# #### CA (California): 392 records, all with taxes due.
# #### Other states like UK, US, VI, etc., also have smaller counts.
# #### The final column ('All') shows a total of 136,010 records, and all of them have taxes due.

# %% [markdown]
# ## 6. Data Preprocessing

# %% [markdown]
# ##### dropping rows in which target variable is 0 that may harm the quality of your analysis or model performance.

# %%
import pandas as pd
# Filter the rows where 'TAX_DUE' is 0
tax_due_zero = df[df['TAX_DUE'] == 0]

# Randomly sample rows where 'TAX_DUE' is 0
sampled_tax_due_zero = tax_due_zero.sample(frac=0.9, random_state=42)

# Drop the sampled rows from the original DataFrame
df2=df.drop(sampled_tax_due_zero.index)

# %%
df2['TAX_DUE'] = df['TAX_DUE'].replace(0, df['TAX_DUE'].mean())

# %%
#this code creates a copy of the orginal dataframe and assigns it to a new variable "df1" for the further purpose.
df1 = df2.copy()
df1.shape
# Out:
# (31290, 18)

# %%
df1.columns
# Out:
# Index(['YR', 'BILL_TYPE', 'BILL_NUM', 'PARCEL_ID', 'TXPR_NAME', 'CO_NAME',
#        'MAIL_ADDR', 'MAIL_ADDR2', 'CITY', 'STATE', 'ZIP1', 'ZIP2',
#        'PROP_LOC_NUM', 'PROP_LOC_NAME', 'LIEN_SOLD', 'BILLED', 'PAID',
#        'TAX_DUE'],
#       dtype='object')

# %% [markdown]
# #### The columns "CO_NAME","MAIL_ADDR2", "LIEN_SOLD" contain almost missing values, so that those can be droped from the dataset.

# %% [markdown]
# ### Remove unnecessary columns:

# %%
# Drop the specified columns
df1.drop(['CO_NAME','MAIL_ADDR2','LIEN_SOLD'],axis=1,inplace=True)

# %%
# column with multicollinearity
# Drop 'PAID' column
df1.drop(columns=['PAID'], inplace=True)

# %% [markdown]
# ### Handling missing values

# %%
#Fill missing categorical values with the column's mode
df1.fillna(df1.mode().iloc[0], inplace=True)

# %%
# Step 1: Convert to numeric (coercing errors to NaN)
df1['PROP_LOC_NUM'] = pd.to_numeric(df1['PROP_LOC_NUM'], errors='coerce')

# Step 2: Check for missing or problematic entries
missing_values = df1[df1['PROP_LOC_NUM'].isna()]

# Step 3: Handle missing or non-numeric values (e.g., drop or fill them)
df1['PROP_LOC_NUM'].fillna(df1['PROP_LOC_NUM'].mean(), inplace=True)  # Example: filling NaNs with mean

# Step 4: Convert to integer type if appropriate
df1['PROP_LOC_NUM'] = df1['PROP_LOC_NUM'].astype(int)

# %%
df1.to_csv('cleaned_residential_property_tax.csv', index=False)

# %%
# finding missing /null values
df1.isnull().sum()
# Out:
# YR               0
# BILL_TYPE        0
# BILL_NUM         0
# PARCEL_ID        0
# TXPR_NAME        0
# MAIL_ADDR        0
# CITY             0
# STATE            0
# ZIP1             0
# ZIP2             0
# PROP_LOC_NUM     0
# PROP_LOC_NAME    0
# BILLED           0
# TAX_DUE          0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31290 entries, 0 to 136044
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YR             31290 non-null  int64
#  1   BILL_TYPE      31290 non-null  object
#  2   BILL_NUM       31290 non-null  int64
#  3   PARCEL_ID      31290 non-null  int64
#  4   TXPR_NAME      31290 non-null  object
#  5   MAIL_ADDR      31290 non-null  object
#  6   CITY           31290 non-null  object
#  7   STATE          31290 non-null  object
#  8   ZIP1           31290 non-null  int64
#  9   ZIP2           31290 non-null  int64
#  10  PROP_LOC_NUM   31290 non-null  int32
#  11  PROP_LOC_NAME  31290 non-null  object
#  12  BILLED         31290 non-null  float64
#  13  TAX_DUE        31290 non-null  float64
# dtypes: float64(2), int32(1), int64(5), object(6)
# memory usage: 3.5+ MB

# %% [markdown]
# ### Handling Outliers

# %% [markdown]
# #### Here IQR method is used for outlier treatement

# %%
# IQR method for outlier detection in 'TAX_DUE'
Q1 = df['TAX_DUE'].quantile(0.25)  # First quartile (25th percentile)
Q3 = df['TAX_DUE'].quantile(0.75)  # Third quartile (75th percentile)
IQR = Q3 - Q1                      # Interquartile range

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers in 'TAX_DUE'
outliers_iqr = df1[(df1['TAX_DUE'] < lower_bound) | (df1['TAX_DUE'] > upper_bound)]

# Print outliers in 'TAX_DUE'
print(outliers_iqr)
# Out:
#           YR    BILL_TYPE  BILL_NUM  PARCEL_ID                   TXPR_NAME  \
# 0       2010  Residential     12351  264169027         LYTTLETON PRISCILLA
# 3       2010  Residential      2671  284074072             BROWN DERMOTH H
# 10      2010  Residential     20736  170029174               TURNER JOHN G
# 11      2010  Residential     15616  240119104                  PEAY NAOMI
# 15      2010  Residential     13822  219211011  MIDDLEFIELD PROPERTIES LLC
# ...      ...          ...       ...        ...                         ...
# 136039  2017  Residential      6958  171094057             DAVIS DEBORAH C
# 136040  2017  Residential     25380  227544074   WASHINGTON DEVELOPERS LLC
# 136041  2017  Residential     16312  147018080         CASTLEROCK 2017 LLC
# 136042  2017  Residential     11083  193055038        IRVING VIOLET LOUISE
# 136044  2017  Residential     25486  227544084   WASHINGTON DEVELOPERS LLC
#
#                              MAIL_ADDR          CITY STATE   ZIP1  ZIP2  \
# 0                      297 BELLEVUE ST      HARTFORD    CT   6120  2104
# 3                         3372 MAIN ST      HARTFORD    CT   6120  1109
# 10                   590 BLUE HILLS AV      HARTFORD    CT   6112  1206
# 11                 120 CLARK ST UNIT A      HARTFORD    CT   6120  1810
# 15                        95 KENYON ST      HARTFORD    CT   6105     0
# ...                                ...           ...   ...    ...   ...
# 136039               421 BLUE HILLS AV      HARTFORD    CT   6112     0
# 136040                5 MARINA VIEW DR       CHESTER    CT   6412     0
# 136041  333 WESTCHESTER AV WEST BUILDI  WHITE PLAINS    NY  10604     0
# 136042            111 EAST 14TH STREET      NEW YORK    NY  10003     0
# 136044                5 MARINA VIEW DR       CHESTER    CT   6412     0
#
#         PROP_LOC_NUM   PROP_LOC_NAME   BILLED  TAX_DUE
# 0                303     BELLEVUE ST   891.34   829.16
# 3               3364         MAIN ST  2373.16   456.76
# 10               594   BLUE HILLS AV  1107.44   687.36
# 11               120   CLARK ST 000A   550.56     9.88
# 15               166  MIDDLEFIELD ST  2799.58    56.41
# ...              ...             ...      ...      ...
# 136039           429  BLUE HILLS AVE  1263.68  1263.68
# 136040           215   WASHINGTON ST  1216.06  1216.06
# 136041           161       HAROLD ST  2592.94  2592.94
# 136042            27    WOODSTOCK ST  2193.42  2193.42
# 136044           333   WASHINGTON ST  1331.66  1331.66
#
# [31290 rows x 14 columns]

# %%
def whisker(col):
    q1,q3 = np.percentile(col,[25,75])
    iqr = q3-q1
    lw = q1 - 1.5*iqr
    uw = q3 + 1.5*iqr
    return lw,uw

# %%
lw, uw = whisker(df1['BILLED'])
print(f'Lower whisker: {lw}, Upper whisker:{uw}')
# Out:
# Lower whisker: -3077.8699999999994, Upper whisker:9098.849999999999

# %% [markdown]
# #### Since the lower whisker is negative (and the column 'BILLED' represent payment, which is usually positive), the lower whisker doesn’t make much practical sense for this type of data. It suggests there are no meaningful lower outliers.

# %%
for i in df1.select_dtypes(include = 'number').columns:
    lw,uw = whisker(df1[i])
    df1[i] = np.where(df1[i] < lw,lw,df1[i])
    df1[i] = np.where(df1[i] > uw,uw,df1[i])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 5))  # Adjust the figure size as needed
numeric_columns = df1.select_dtypes(include='number').columns

for i, col in enumerate(numeric_columns):
    plt.subplot(1, len(numeric_columns), i + 1)  # Adjust subplot arrangement dynamically
    sns.boxplot(y=df1[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### All Outliers are removed

# %% [markdown]
# ## 7. Visualization

# %%
# Histograms for numerical columns after outlier treatment
# Histograms and Distribution Plots
df1.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
# Scatter Plots
sns.pairplot(df1, vars=['YR','ZIP1','TAX_DUE'])
plt.show()

# %%
# pairplot - To visualize relationship between multiple pairs of variables
sns.pairplot(df1)

# %% [markdown]
# * The diagonal represents histograms of individual variables, showing their distribution.
# * YR (year) variable shows a high concentration around 2016, with a sharp peak.
# * The triangular pattern, indicating that higher values of BILLED correspond to higher values of TAX_DUE.
# * Many of the scatter plots are dense, because of discrete values or categorical data in the dataset.

# %%
# Box Plots
plt.figure(figsize=(12, 6))
sns.boxplot(x='STATE', y='TAX_DUE', data=df1)
plt.xticks(rotation=45)
plt.title('TAX_DUE Distribution by STATE')
plt.show()

# %% [markdown]
# * This visualization highlights the variation in tax dues across different states.
# * states are listed in an abbreviated form (e.g., CT, MD, AZ, PA, etc.)
# * Some states show negative tax dues, indicating instances where people received refunds or had no tax due, such as GA and MO.
# * Certain states have more centralized distributions, indicating less variation in TAX_DUE, such as NJ and NH.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(df1['TAX_DUE'], bins=30, kde=True)
plt.title('Distribution of TAX_DUE Categories')
plt.xlabel('TAX_DUE')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Count Distribution:
# * The count values range from 0 to 12000, showing how many records fall within each TAX_DUE range.
# * The highest peak in the count occurs at a TAX_DUE value of 800, where the count reaches 12,000. This indicates that most properties or records have a tax due around this value, suggesting it's a common or average tax amount in your data.

# %% [markdown]
# #### Higher TAX_DUE Values:
# * As TAX_DUE increases towards 4000, the count decreases significantly, with around 4,000 records at that tax level.
# * This shows that fewer records have high tax dues, implying that higher tax amounts are less frequent in your dataset.

# %% [markdown]
# #### Overall Trend:
# * The histogram highlights that most tax dues cluster around lower values (close to 800), with the distribution tapering off as the tax due rises, particularly toward the upper limit of 4000.
# *  This reflects an imbalance where the majority of properties or individuals have relatively moderate tax liabilities, while only a smaller subset is taxed more heavily.
# * This analysis suggests a right-skewed distribution, where lower tax dues are much more common than higher ones.

# %%
# Line Plots (for time-series data, if applicable)
plt.figure(figsize=(12, 6))
sns.lineplot(x='YR', y='TAX_DUE', data=df1)
plt.title('year vs.tax_due')
plt.show()

# %% [markdown]
# #### The trend in the line plot of Year vs. Tax Due shows two distinct phases:
#
# * 2012 to 2014: During this period, the tax due remains relatively stable, fluctuating between 800 and 1000. This could indicate consistent property   values or tax rates, with no significant economic changes impacting tax dues.
# * 2014-2015: Tax due is slightly decreases upto below 800. This may indicate the lower property values at that time.
#
# * 2015 to 2017: From 2015 onwards, there is a noticeable increase, with tax dues rising to between 1200 and 1600. This suggests a shift, possibly due to rising property values, tax policy changes, or other economic factors.
#
# The sharp increase in tax due after 2015 indicates an external influence, such as market changes or revised tax regulations.

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df1[numeric_columns].corr(),annot=True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## 8. Feature Engineering

# %% [markdown]
# #### Encode categorical features to numerical using techniques like label encoding to prepare thedata for machine learning algorithms. Use Label encoding for ordinal data.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31290 entries, 0 to 136044
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YR             31290 non-null  float64
#  1   BILL_TYPE      31290 non-null  object
#  2   BILL_NUM       31290 non-null  float64
#  3   PARCEL_ID      31290 non-null  float64
#  4   TXPR_NAME      31290 non-null  object
#  5   MAIL_ADDR      31290 non-null  object
#  6   CITY           31290 non-null  object
#  7   STATE          31290 non-null  object
#  8   ZIP1           31290 non-null  float64
#  9   ZIP2           31290 non-null  float64
#  10  PROP_LOC_NUM   31290 non-null  float64
#  11  PROP_LOC_NAME  31290 non-null  object
#  12  BILLED         31290 non-null  float64
#  13  TAX_DUE        31290 non-null  float64
# dtypes: float64(8), object(6)
# memory usage: 3.6+ MB

# %%
# Perform label encoding on the feature columns
#drop_first=True: This parameter is set to True to drop the first level for each categorical variable after encoding. 
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# List of columns to apply label encoding
columns_to_encode = ['BILL_TYPE','TXPR_NAME', 'MAIL_ADDR', 'CITY', 'STATE', 'PROP_LOC_NAME']

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each specified column
for column in columns_to_encode:
    df1[column] = label_encoder.fit_transform(df1[column].astype(str))

# Display the first few rows of the DataFrame
print(df1.head())
# Out:
#         YR  BILL_TYPE  BILL_NUM    PARCEL_ID  TXPR_NAME  MAIL_ADDR  CITY  \
# 0   2012.0          0   12351.0  264169027.0       7957       6737   232
# 3   2012.0          0    2671.0  284074072.0       1970       7618   232
# 10  2012.0          0   20736.0  170029174.0      13507      10640   232
# 11  2012.0          0   15616.0  240119104.0      10104       1381   232
# 15  2012.0          0   13822.0  219211011.0       8843      13262   232
#
#     STATE    ZIP1    ZIP2  PROP_LOC_NUM  PROP_LOC_NAME   BILLED  TAX_DUE
# 0       7  6120.0  2104.0         303.0             71   891.34   829.16
# 3       7  6120.0  1109.0         477.5            677  2373.16   456.76
# 10      7  6112.0  1206.0         477.5             80  1107.44   687.36
# 11      7  6120.0  1810.0         120.0            170   550.56     9.88
# 15      7  6105.0     0.0         166.0            784  2799.58    56.41

# %% [markdown]
# ### Scaling using StandardScaler

# %%
# Scaling using StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = df1.drop(columns=['TAX_DUE'])  # Features (all columns except target)
y = df1['TAX_DUE']                   # Target variable
X_scaled = scaler.fit_transform(X)
# Convert the result back to a DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled
# Out:
#              YR  BILL_TYPE  BILL_NUM  PARCEL_ID  TXPR_NAME  MAIL_ADDR  \
# 0     -2.089695        0.0 -0.171237   1.366996   0.252681  -0.111442
# 1     -2.089695        0.0 -1.128293   1.798162  -1.104619   0.105940
# 2     -2.089695        0.0  0.657782  -0.672181   1.510909   0.851600
# 3     -2.089695        0.0  0.151571   0.846047   0.739422  -1.433003
# 4     -2.089695        0.0 -0.025801   0.393154   0.453544   1.498564
# ...         ...        ...       ...        ...        ...        ...
# 31285  0.751568        0.0 -0.704440  -0.649115  -0.740526   0.414123
# 31286  0.751568        0.0  1.116931   0.573657   1.625623   0.615713
# 31287  0.751568        0.0  0.220384  -1.170628  -0.967461   0.099031
# 31288  0.751568        0.0 -0.296604  -0.173415  -0.070831  -1.541324
# 31289  0.751568        0.0  1.127412   0.573658   1.625623   0.615713
#
#            CITY     STATE      ZIP1      ZIP2  PROP_LOC_NUM  PROP_LOC_NAME  \
# 0     -0.236635 -0.367507  0.629204  1.274288      0.999696      -1.401007
# 1     -0.236635 -0.367507  0.629204  0.388590      2.177078       0.177340
# 2     -0.236635 -0.367507 -0.035031  0.474934      2.177078      -1.377566
# 3     -0.236635 -0.367507  0.629204  1.012584     -0.235038      -1.143158
# 4     -0.236635 -0.367507 -0.616236 -0.598586      0.075332       0.456026
# ...         ...       ...       ...       ...           ...            ...
# 31285 -0.236635 -0.367507 -0.035031 -0.598586      1.849840      -1.374962
# 31286 -1.387562 -0.367507  1.750100 -0.598586      0.405944       1.198318
# 31287  2.673565  2.728692  1.750100 -0.598586      0.041596      -0.208131
# 31288  0.832082  2.728692  1.750100 -0.598586     -0.862526       1.888519
# 31289 -1.387562 -0.367507  1.750100 -0.598586      1.202111       1.198318
#
#          BILLED
# 0     -1.045644
# 1     -0.486472
# 2     -0.964098
# 3     -1.174239
# 4     -0.325561
# ...         ...
# 31285 -0.905140
# 31286 -0.923110
# 31287 -0.403537
# 31288 -0.554298
# 31289 -0.879487
#
# [31290 rows x 13 columns]

# %% [markdown]
# ## 9. Data Splitting

# %%
#Splitting the dataset into 80-20, that is, 80% of the data is for training and 20% of the data is for testing.
import pandas as pd
from sklearn.model_selection import train_test_split
# Define your features (X) and target variable (y)
X = df1.drop(columns=['TAX_DUE'])  # Features (all columns except target)
y = df1['TAX_DUE']                   # Target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Display the shapes of the resulting datasets
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (25032, 13)
# X_test shape: (6258, 13)
# y_train shape: (25032,)
# y_test shape: (6258,)

# %% [markdown]
# ## 10.Model Selection

# %% [markdown]
# ### Models Selected:
# * LinearRegression,
# * DecisionTreeRegressor,
# * ExtraTreeRegressor,
# * RandomForestRegressor,
# * GradientBoostingRegressorssor.

# %% [markdown]
# ## 11. Model Training & Evaluation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Initialize lists to store model metrics
model_name = []
RMSE = []
MSE = []
MAE = []
R2_score = []

# List of models to evaluate
models = [
    LinearRegression(),
    DecisionTreeRegressor(),
    ExtraTreeRegressor(),
    RandomForestRegressor(),
    GradientBoostingRegressor()
]

# Loop through each model, fit, and evaluate
for model in models:
    model.fit(X_train, y_train)  # Ensure you use 'X_train' here
    
    prediction = model.predict(X_test)  # Use 'X_test' for predictions
    
    model_name.append(model.__class__.__name__)
    
    RMSE.append(mean_squared_error(y_test, prediction, squared=False))
    MSE.append(mean_squared_error(y_test, prediction))
    MAE.append(mean_absolute_error(y_test, prediction))
    R2_score.append(r2_score(y_test, prediction) * 100)

# %%
models_df = pd.DataFrame({"Model-Name":model_name, "RMSE": RMSE, "MSE":MSE, "MAE":MAE, "R2_Score":R2_score})
models_df = models_df.set_index('Model-Name')
models_df.sort_values("R2_Score", ascending = False)
# Out:
#                                  RMSE            MSE         MAE   R2_Score
# Model-Name
# RandomForestRegressor      565.893972  320235.987103  278.596580  73.412896
# GradientBoostingRegressor  619.258622  383481.241065  321.055570  68.162055
# LinearRegression           815.498205  665037.322595  601.546647  44.786291
# DecisionTreeRegressor      818.969454  670710.966206  338.610105  44.315245
# ExtraTreeRegressor         840.514671  706464.912385  350.269974  41.346829

# %% [markdown]
# ### 1. RandomForestRegressor:
# #### Best overall performance with an R² Score 73.41
# ### 2.GradientBoostingRegressor:
# #### Second best in terms of R² Score (68.16%) indicating good performance ,but less than RandomForest.
# ### 3.LinearRegression :
# #### R² Score of 44.78%, showing slightly worse performance compared to Decisiontreeregressor.
# ### 4. DecisionTreeRegressor and 5.ExtraTreeRegressor :
# #### Similar performance to LinearRegression with R² Score of 44.31 and 41.34%.

# %% [markdown]
# ## 12. Feature Selection And 13.Model Evaluation

# %% [markdown]
# ### 1. SelecKBbest

# %%
from sklearn.feature_selection import SelectKBest, f_regression
# Apply SelectKBest with f_regression
selector_kbest = SelectKBest(score_func=f_regression, k=10)
x_train_kbest = selector_kbest.fit_transform(X_train, y_train)
x_test_kbest = selector_kbest.transform(X_test)

# Get the names of the selected features
selected_indices_kbest = selector_kbest.get_support(indices=True)
selected_features_kbest = X_train.columns[selected_indices_kbest]
print("Selected features using SelectKBest:", selected_features_kbest)

# Initialize lists to store results
model_name = []
RMSE = []
MSE = []
MAE = []
R2_score = []

# List of models to train
models = [
    LinearRegression(),
    DecisionTreeRegressor(),
    ExtraTreeRegressor(),
    RandomForestRegressor(),
    GradientBoostingRegressor()
]

# Train and evaluate each model
for model in models:
    model.fit(x_train_kbest, y_train)
    prediction = model.predict(x_test_kbest)
    
    model_name.append(model.__class__.__name__)
    RMSE.append(mean_squared_error(y_test, prediction, squared=False))
    MSE.append(mean_squared_error(y_test, prediction))
    MAE.append(mean_absolute_error(y_test, prediction))
    R2_score.append(r2_score(y_test, prediction) * 100)

# Create a DataFrame to display the results
models_df1_kbest = pd.DataFrame({"Model-Name": model_name, "RMSE": RMSE, "MSE": MSE, "MAE": MAE, "R2_Score": R2_score})
models_df1_kbest = models_df1_kbest.set_index('Model-Name')
models_d1f_kbest = models_df1_kbest.sort_values("R2_Score", ascending=False)

# Print the results
print("Results using SelectKBest:")
print(models_df1_kbest)
# Out:
# Selected features using SelectKBest: Index(['YR', 'BILL_NUM', 'TXPR_NAME', 'CITY', 'STATE', 'ZIP1', 'ZIP2',
#        'PROP_LOC_NUM', 'PROP_LOC_NAME', 'BILLED'],
#       dtype='object')
# Results using SelectKBest:
#                                  RMSE            MSE         MAE   R2_Score
# Model-Name
# LinearRegression           815.974220  665813.928449  602.035148  44.721814
# DecisionTreeRegressor      848.520155  719986.453832  354.517403  40.224223
# ExtraTreeRegressor         866.748856  751253.578827  365.424332  37.628318
# RandomForestRegressor      583.085141  339988.282187  290.435792  71.772992
# GradientBoostingRegressor  622.437960  387429.014004  317.748082  67.834297

# %% [markdown]
# ### 2.SelectFromModel with Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# Apply SelectFromModel with Lasso
lasso = Lasso(alpha=0.1)
selector_lasso = SelectFromModel(lasso)
selector_lasso.fit(X_train, y_train)

# Get the selected feature indices
selected_indices_lasso = selector_lasso.get_support(indices=True)

# Get the names of the selected features
selected_features_lasso = X_train.columns[selected_indices_lasso]
print("Selected features using SelectFromModel with Lasso:", selected_features_lasso)

# Use the selected features to train and evaluate the models
x_train_lasso = X_train[selected_features_lasso]
x_test_lasso = X_test[selected_features_lasso]

# Initialize lists to store results
model_name = []
RMSE = []
MSE = []
MAE = []
R2_score = []

# Train and evaluate each model
for model in models:
    model.fit(x_train_lasso, y_train)
    prediction = model.predict(x_test_lasso)
    
    model_name.append(model.__class__.__name__)
    RMSE.append(mean_squared_error(y_test, prediction, squared=False))
    MSE.append(mean_squared_error(y_test, prediction))
    MAE.append(mean_absolute_error(y_test, prediction))
    R2_score.append(r2_score(y_test, prediction) * 100)

# Create a DataFrame to display the results
models_df1_lasso = pd.DataFrame({"Model-Name": model_name, "RMSE": RMSE, "MSE": MSE, "MAE": MAE, "R2_Score": R2_score})
models_df1_lasso = models_df1_lasso.set_index('Model-Name')
models_df1_lasso = models_df1_lasso.sort_values("R2_Score", ascending=False)

# Print the results
print("Results using SelectFromModel with Lasso:")
print(models_df1_lasso)
# Out:
# Selected features using SelectFromModel with Lasso: Index(['YR', 'BILL_NUM', 'PARCEL_ID', 'TXPR_NAME', 'MAIL_ADDR', 'CITY',
#        'STATE', 'ZIP1', 'ZIP2', 'PROP_LOC_NUM', 'PROP_LOC_NAME', 'BILLED'],
#       dtype='object')
# Results using SelectFromModel with Lasso:
#                                  RMSE            MSE         MAE   R2_Score
# Model-Name
# RandomForestRegressor      561.971225  315811.657358  276.447406  73.780219
# GradientBoostingRegressor  619.272464  383498.385074  321.045330  68.160632
# DecisionTreeRegressor      806.027725  649680.693898  331.425527  46.061252
# LinearRegression           815.498205  665037.322595  601.546647  44.786291
# ExtraTreeRegressor         816.385035  666484.525092  344.060261  44.666139

# %% [markdown]
# ### 3.Select features using Variance Threshold

# %%
from sklearn.feature_selection import VarianceThreshold

# Apply Variance Threshold
threshold = 0.1  # Set a variance threshold
selector_variance = VarianceThreshold(threshold=threshold)
x_train_variance = selector_variance.fit_transform(X_train)
x_test_variance = selector_variance.transform(X_test)

# Get the selected feature indices
selected_indices_variance = selector_variance.get_support(indices=True)
selected_features_variance = X_train.columns[selected_indices_variance]
print("Selected features using Variance Threshold:", selected_features_variance)

# Initialize lists to store results
model_name = []
RMSE = []
MSE = []
MAE = []
R2_score = []

# List of models to train
models = [
    LinearRegression(),
    DecisionTreeRegressor(),
    ExtraTreeRegressor(),
    RandomForestRegressor(),
    GradientBoostingRegressor()
]

# Train and evaluate each model
for model in models:
    model.fit(x_train_variance, y_train)
    prediction = model.predict(x_test_variance)
    
    model_name.append(model.__class__.__name__)
    RMSE.append(mean_squared_error(y_test, prediction, squared=False))
    MSE.append(mean_squared_error(y_test, prediction))
    MAE.append(mean_absolute_error(y_test, prediction))
    R2_score.append(r2_score(y_test, prediction) * 100)

# Create a DataFrame to display the results
models_df1_variance = pd.DataFrame({
    "Model-Name": model_name,
    "RMSE": RMSE,
    "MSE": MSE,
    "MAE": MAE,
    "R2_Score": R2_score
})
models_df1_variance = models_df1_variance.set_index('Model-Name')
models_df1_variance = models_df1_variance.sort_values("R2_Score", ascending=False)
# Out:
# Selected features using Variance Threshold: Index(['YR', 'BILL_NUM', 'PARCEL_ID', 'TXPR_NAME', 'MAIL_ADDR', 'CITY',
#        'STATE', 'ZIP1', 'ZIP2', 'PROP_LOC_NUM', 'PROP_LOC_NAME', 'BILLED'],
#       dtype='object')

# %%
# Print results
print("Results using SelectKBest:")
print(models_df1_kbest)

print("\nResults using SelectFromModel with Lasso:")
print(models_df1_lasso)

print("\nResults using Variance Threshold:")
print(models_df1_variance)
# Out:
# Results using SelectKBest:
#                                  RMSE            MSE         MAE   R2_Score
# Model-Name
# LinearRegression           815.974220  665813.928449  602.035148  44.721814
# DecisionTreeRegressor      848.520155  719986.453832  354.517403  40.224223
# ExtraTreeRegressor         866.748856  751253.578827  365.424332  37.628318
# RandomForestRegressor      583.085141  339988.282187  290.435792  71.772992
# GradientBoostingRegressor  622.437960  387429.014004  317.748082  67.834297
#
# Results using SelectFromModel with Lasso:
#                                  RMSE            MSE         MAE   R2_Score
# Model-Name
# RandomForestRegressor      561.971225  315811.657358  276.447406  73.780219
# GradientBoostingRegressor  619.272464  383498.385074  321.045330  68.160632
# DecisionTreeRegressor      806.027725  649680.693898  331.425527  46.061252
# LinearRegression           815.498205  665037.322595  601.546647  44.786291
# ExtraTreeRegressor         816.385035  666484.525092  344.060261  44.666139
#
# Results using Variance Threshold:
#                                  RMSE            MSE         MAE   R2_Score
# Model-Name
# RandomForestRegressor      563.912105  317996.861621  276.874265  73.598796
# GradientBoostingRegressor  619.245561  383465.064869  321.024537  68.163398
# DecisionTreeRegressor      815.426935  664921.086662  335.641561  44.795941
# LinearRegression           815.498205  665037.322595  601.546647  44.786291
# ExtraTreeRegressor         844.535970  713241.004161  354.401805  40.784254

# %% [markdown]
# ### Random Forest Feature Importance Analysis

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# Initialize the RandomForestRegressor with our preferred parameters
rf_model = RandomForestRegressor()

# Train the model on your training data
rf_model.fit(X_train, y_train)

# Get feature importances from the trained model
feature_importances = rf_model.feature_importances_

# Create a DataFrame to display feature names and their importance scores
feature_importance_df1 = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
})

# Sort features by importance in descending order
feature_importance_df1 = feature_importance_df1.sort_values(by='Importance', ascending=False)

# Display the top 10 most important features
top_features = feature_importance_df1.head(10)
print("Top 10 Important Features:")
print(top_features)

# Plotting feature importances
plt.figure(figsize=(10, 6))
plt.barh(top_features['Feature'], top_features['Importance'], align='center')
plt.xlabel('Importance Score')
plt.ylabel('Features')
plt.title('Top 10 Feature Importances')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Top 10 Important Features:
#           Feature  Importance
# 12         BILLED    0.401567
# 0              YR    0.285385
# 3       PARCEL_ID    0.063151
# 5       MAIL_ADDR    0.043804
# 4       TXPR_NAME    0.042481
# 10   PROP_LOC_NUM    0.037035
# 11  PROP_LOC_NAME    0.036267
# 2        BILL_NUM    0.031287
# 6            CITY    0.020578
# 8            ZIP1    0.015521

# %% [markdown]
# * #### BILLED(40.15% feature importance):Most crucial factor in predicting residential tax due.
# * #### YR(28.53% feature importance):Second most influential feature.
# * #### However other features are contributing small influence in prediction

# %% [markdown]
# ## 14.Hyperparameter Tuning

# %%
# tunning the Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(n_estimators=120)
clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 0.9621082096523719

# %%
# Define parameter grid for Random Forest Regressor
from sklearn.model_selection import GridSearchCV
param_grid_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 10],
    'min_samples_leaf': [1, 5],
    'max_features': ['auto', 'sqrt', 'log2']
}

# Initialize Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42)

# Perform Grid Search with cross-validation
grid_search_rf = GridSearchCV(estimator=rf_model, param_grid=param_grid_rf, scoring='neg_mean_squared_error', cv=3, n_jobs=-1, verbose=2)
grid_search_rf.fit(x_train_kbest, y_train)

# Get the best model from grid search
best_rf_model = grid_search_rf.best_estimator_
y_pred = best_rf_model.predict(x_test_kbest)

# Calculate evaluation metrics
rmse = mean_squared_error(y_test, y_pred, squared=False)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred) * 100

# Print the results
print("Best Parameters:", grid_search_rf.best_params_)
print("RMSE:", rmse)
print("MSE:", mse)
print("MAE:", mae)
print("R2 Score:", r2)

# Create a DataFrame with the results
results_df = pd.DataFrame({
    "Model-Name": ["RandomForestRegressor"],
    "RMSE": [rmse],
    "MSE": [mse],
    "MAE": [mae],
    "R2 Score": [r2]
})

results_df.set_index('Model-Name', inplace=True)
print(results_df)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# Best Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# RMSE: 569.603327479079
# MSE: 324447.9506752389
# MAE: 280.71861527928854
# R2 Score: 73.06320392869625
#                              RMSE            MSE         MAE   R2 Score
# Model-Name
# RandomForestRegressor  569.603327  324447.950675  280.718615  73.063204

# %% [markdown]
# ### The RandomForestRegressor model performs well on my dataset, as indicated by the high R2 score (73.06%). This suggests that the model captures a significant amount of variability in the target variable.

# %% [markdown]
# ## 15.Model Deployment

# %%
import joblib
import os

# Assuming best_rf_model contains your trained Random Forest Regressor model
best_model = best_rf_model  # Replace 'best_rf_model' with your RandomForestRegressor instance

# Define the filename to save the model
filename = 'random_forest_regressor_model.joblib'

# Save the model using joblib
joblib.dump(best_model, filename)
print("Model saved successfully.")

# Check if the model file exists
if os.path.isfile(filename):
    print("Model file exists.")
else:
    print("Model file does not exist.")

# Load the model from the file using joblib
loaded_model = joblib.load(filename)
print("Model loaded successfully.")
# Out:
# Model saved successfully.
# Model file exists.
# Model loaded successfully.

# %% [markdown]
# ## 16.Test with unseen data

# %%
# Predict on unseen data
# Assuming new_data is our new unseen data array
new_data = np.random.rand(10,10) #Example of 10 new samples with 7 features each

# Predict on unseen data
predictions = best_model.predict(new_data)
print('Predictions on unseen data:', predictions)
# Out:
# Predictions on unseen data: [1112.27391813 1134.31211617 2534.02867499 1498.87418397 2540.52802772
#  2401.23341029 1061.36037462 2468.74438535 2261.18451359 1728.66062082]

# %% [markdown]
# #### The predictions range from approximately 1061.36 to 2540.53, indicating that your model has outputted a wide range of values. The lowest prediction is relatively small (around 1061), while the highest prediction (around 2541) is significantly larger. This suggests that the target variable has a diverse range, possibly indicating varying levels of tax dues.

# %% [markdown]
# ## 17.Interpretation of Results:
# * #### Features such as 'YR','BILLED' were found to be significant contributors to the prediction of residential tax_due.
# * #### we can say that Year of the property tax payment and The amount billed for taxes are the factors significantly affect the tax due of the property.
# * #### other features are showing less impact on tax due prediction
# * The lowest prediction (~1061) suggests that for certain properties or records, the tax due is estimated to be relatively small, likely for properties with lower values or tax rates.
# * The highest prediction (~2541) indicates that some properties or records are expected to have significantly higher tax dues, possibly due to higher property values, tax rates, or other influencing factors.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### In this project, I aimed to predict residential tax due using a diverse dataset containing various features. Through meticulous data preprocessing, feature engineering, and model selection, I was able to develop and evaluate multiple regression models.

# %% [markdown]
# ## 18. Limitations:
#
# * most of the features doesn't provide any significant connection with the target variable
# * The model performance is sufficient but cannot say it as a perfect one.
# * Challenges: we encountered limitations such as data quality issues, potential feature correlation, and the absence of external factors that could influence residential tax.
# * Feature Importance: Features such as 'YR','BILLED' were found to be significant contributors to the prediction of residential tax_due.
# * Had to reduce the dataset size to eliminate the problem of time taken for model training and imbalanced data ('0' values in the target variable)

# %% [markdown]
# ## 19.Future Work:

# %% [markdown]
# ### To enhance the predictive performance and reliability of our model, future efforts could focus on:

# %% [markdown]
# * Consider adding more features to enhance predictive power
# * Addresss imbalanced data through resampling techniques.
# * Collect and integrate more diverse and updated data.
# * Explore advanced machine learning techniques and model ensembling.
